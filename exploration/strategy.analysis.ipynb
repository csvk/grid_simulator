# %%
from data import Data
import json
from plotting import CandlePlot
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
data_path = '../data/'
out_path = 'D:/Trading/ml4t-data/hedged-grid/'
instruments = "../data/instruments.json"

# %%
OPEN_KEYS = ('SIZE', 'TRIG', 'ENT', 'TP', 'SL', 'TSL', 'PAR', 'COVS')
CLOSED_KEYS = ('SIZE', 'TRIG', 'ENT', 'PAR', 'COVS', 'EXIT', 'PIPS')

# %%
ticker = 'EUR_USD'
freq = 'M5'
sim_no = 81

# %%
results = pd.read_csv(out_path + f'{ticker}-{freq}-{sim_no}-events.csv')

# %%
d = Data(source=results, ticker=ticker, instruments=instruments)

# %%
# summary

# %%
d.prepare_fast_data('d')

# %%
d.df['d'].head(1)
# Out:
#                   time    mid_c    bid_c    ask_c  \
# 0  2016-01-07 00:00:00  1.07786  1.07777  1.07795
#
#                                           open_longs  \
# 0  {1: (100, 1.07786, 1.07795, 1.07986, 1.07186, ...
#
#                                          open_shorts closed_longs  \
# 0  {1: (100, 1.07786, 1.07777, 1.07586, 1.08386, ...          NaN
#
#   closed_shorts   events  cum_long_position  cum_short_position  \
# 0           NaN  ['ENT']              100.0               100.0
#
#    open_long_count  open_short_count  closed_long_count  closed_short_count  \
# 0              1.0               1.0                0.0                 0.0
#
#    unrealised_pnl  realised_pnl  ac_bal  net_bal  margin_used  cash_bal  \
# 0           -0.02           0.0  1000.0   999.98         6.67       NaN
#
#    gross_bal
# 0     1000.0

# %%
d.df['d'].open_long_count.max(), d.df['d'].open_short_count.max()
# Out:
# (188.0, 185.0)

# %%
d.df['d'].margin_used.max()
# Out:
# 836.67

# %%
d.df['d'][d.df['d']['events'].str.contains('MC')].head()
# Out:
# Empty DataFrame
# Columns: [time, mid_c, bid_c, ask_c, open_longs, open_shorts, closed_longs, closed_shorts, events, cum_long_position, cum_short_position, open_long_count, open_short_count, closed_long_count, closed_short_count, unrealised_pnl, realised_pnl, ac_bal, net_bal, margin_used, cash_bal, gross_bal]
# Index: []

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['gross_bal'])
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.show_plot()

# %%
d.df['d'].describe()
# Out:
#              mid_c        bid_c        ask_c  cum_long_position  \
# count  1640.000000  1640.000000  1640.000000         1640.00000
# mean      1.112444     1.112359     1.112529         5826.95122
# std       0.017572     0.017571     0.017573         5754.45864
# min       1.077860     1.077770     1.077940            0.00000
# 25%       1.099557     1.099487     1.099633          800.00000
# 50%       1.112010     1.111930     1.112115         3000.00000
# 75%       1.127772     1.127695     1.127850        11100.00000
# max       1.161020     1.160960     1.161080        18800.00000
#
#        cum_short_position  open_long_count  open_short_count  \
# count         1640.000000      1640.000000       1640.000000
# mean          5957.804878        58.269512         59.578049
# std           5941.855758        57.544586         59.418558
# min              0.000000         0.000000          0.000000
# 25%            700.000000         8.000000          7.000000
# 50%           3050.000000        30.000000         30.500000
# 75%          11700.000000       111.000000        117.000000
# max          18500.000000       188.000000        185.000000
#
#        closed_long_count  closed_short_count  unrealised_pnl  realised_pnl  \
# count        1640.000000         1640.000000     1640.000000   1640.000000
# mean            3.345122            3.095122      -31.668348     -0.059616
# std            12.832964           11.965661       32.090870     10.566602
# min             0.000000            0.000000     -174.890000   -134.470000
# 25%             0.000000            0.000000      -53.642500      0.000000
# 50%             0.000000            0.000000      -17.710000      0.000000
# 75%             1.000000            0.000000       -4.505000      0.180000
# max           160.000000          160.000000        0.930000     86.030000
#
#             ac_bal      net_bal  margin_used  cash_bal    gross_bal
# count  1640.000000  1640.000000  1640.000000       0.0  1640.000000
# mean   1063.757726  1032.089378   392.826317       NaN  1063.757726
# std      74.594020    60.012959   353.637412       NaN    74.594020
# min     885.120000   882.420000     6.670000       NaN   885.120000
# 25%    1012.312500   997.755000    56.670000       NaN  1012.312500
# 50%    1045.560000  1020.155000   213.330000       NaN  1045.560000
# 75%    1107.660000  1060.945000   836.670000       NaN  1107.660000
# max    1293.040000  1196.120000   836.670000       NaN  1293.040000

# %%
d.df['d'][d.df['d'].events.str.contains('MC')]
# Out:
# Empty DataFrame
# Columns: [time, mid_c, bid_c, ask_c, open_longs, open_shorts, closed_longs, closed_shorts, events, cum_long_position, cum_short_position, open_long_count, open_short_count, closed_long_count, closed_short_count, unrealised_pnl, realised_pnl, ac_bal, net_bal, margin_used, cash_bal, gross_bal]
# Index: []

# %%
# my_cols = ['time', 'mid_c', 'bid_c', 'ask_c', 'events', 'cum_long_position',
#        'cum_short_position', 'open_long_count', 'open_short_count',
#        'closed_long_count', 'closed_short_count', 'unrealised_pnl',
#        'realised_pnl', 'ac_bal', 'net_bal', 'margin_used', 'cash_bal',
#        'gross_bal']
# d.df['d'][my_cols].to_csv(out_path + f'{ticker}-{freq}-{sim_no}-events-without-trades.csv', index=False)

# %%
d.df['d'].iloc[33:37]
# Out:
#                    time    mid_c    bid_c    ask_c  \
# 33  2016-01-08 15:25:00  1.08906  1.08897  1.08916
# 34  2016-01-08 17:20:00  1.08718  1.08709  1.08726
# 35  2016-01-08 18:10:00  1.08997  1.08989  1.09005
# 36  2016-01-08 20:35:00  1.09199  1.09192  1.09206
#
#                                            open_longs  \
# 33  {36: (100, 1.09186, 1.09319, 1.09386, 1.07986,...
# 34  {36: (100, 1.09186, 1.09319, 1.09386, 1.07986,...
# 35  {36: (100, 1.09186, 1.09319, 1.09386, 1.07986,...
# 36  {36: (100, 1.09186, 1.09319, 1.09386, 1.07986,...
#
#                                           open_shorts  \
# 33  {69: (100, 1.08586, 1.08152, 1.08386, 1.09786,...
# 34  {69: (100, 1.08586, 1.08152, 1.08386, 1.09786,...
# 35  {69: (100, 1.08586, 1.08152, 1.08386, 1.09786,...
# 36  {69: (100, 1.08586, 1.08152, 1.08386, 1.09786,...
#
#                                          closed_longs closed_shorts  \
# 33                                                NaN           NaN
# 34                                                NaN           NaN
# 35                                                NaN           NaN
# 36  {58: (100, 1.08986, 1.08999, 0, {1.08786: 88, ...           NaN
#
#                               events  cum_long_position  cum_short_position  \
# 33                           ['COV']             4000.0              2200.0
# 34                  ['COV', 'EFAIL']             4000.0              4100.0
# 35                  ['COV', 'EFAIL']             5900.0              4100.0
# 36  ['PARUNL', 'TP', 'COV', 'EFAIL']             6400.0              4100.0
#
#     open_long_count  open_short_count  closed_long_count  closed_short_count  \
# 33             40.0              22.0                0.0                 0.0
# 34             40.0              41.0                0.0                 0.0
# 35             59.0              41.0                0.0                 0.0
# 36             64.0              41.0               20.0                 0.0
#
#     unrealised_pnl  realised_pnl   ac_bal  net_bal  margin_used  cash_bal  \
# 33          -13.00          0.00  1006.29   993.29       206.67       NaN
# 34          -16.56          0.00  1006.29   989.73       270.00       NaN
# 35          -16.99          0.00  1006.29   989.30       333.33       NaN
# 36          -19.34          5.67  1011.96   992.62       350.00       NaN
#
#     gross_bal
# 33    1006.29
# 34    1006.29
# 35    1006.29
# 36    1011.96

# %%
# i = 164
# total_pips = 0
# for trade_no, trade in d.to_dict_of_dicts('open_longs', OPEN_KEYS, i).items():
#     pips = round((d.fdata('ask_c',  i) - trade['ENT']) * pow(10, -d.ticker['pipLocation']), 1)
#     total_pips += pips
#     print(trade, pips)
# print(total_pips)

# %%
# i = 164
# total_pips = 0
# for trade_no, trade in d.to_dict_of_dicts('open_shorts', OPEN_KEYS, i).items():
#     pips = round((trade['ENT'] - d.fdata('bid_c',  i)) * pow(10, -d.ticker['pipLocation']), 1)
#     total_pips += pips
#     print(trade, pips)
# print(total_pips)
