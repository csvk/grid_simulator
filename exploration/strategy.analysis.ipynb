# %%
from data import Data
import json
from plotting import CandlePlot
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
data_path = '../data/'
out_path = 'D:/Trading/ml4t-data/hedged-grid/'
instruments = "../data/instruments.json"

# %%
OPEN_KEYS = ('SIZE', 'TRIG', 'ENT', 'TP', 'SL', 'TSL', 'PAR', 'COVS')
CLOSED_KEYS = ('SIZE', 'TRIG', 'ENT', 'PAR', 'COVS', 'EXIT', 'PIPS')

# %%
ticker = 'EUR_USD'
freq = 'M5'
sim_no = 51

# %%
results = pd.read_csv(out_path + f'{ticker}-{freq}-{sim_no}-events.csv')

# %%
d = Data(source=results, ticker=ticker, instruments=instruments)

# %%
# summary

# %%
d.prepare_fast_data('d')

# %%
d.df['d'].head()
# Out:
#                   time    mid_c    bid_c    ask_c  \
# 0  2016-01-07 00:00:00  1.07786  1.07777  1.07795
# 1  2016-01-07 01:50:00  1.08100  1.08092  1.08109
# 2  2016-01-07 08:05:00  1.07786  1.07778  1.07794
# 3  2016-01-07 09:00:00  1.08174  1.08166  1.08183
# 4  2016-01-07 09:15:00  1.08509  1.08502  1.08516
#
#                                           open_longs  \
# 0  {1: (100, 1.07786, 1.07795, 1.08086, 1.06886, ...
# 1  {2: (100, 1.08086, 1.08109, 1.08686, 1.06286, ...
# 2  {2: (100, 1.08086, 1.08109, 1.08686, 1.06286, ...
# 3  {2: (100, 1.08086, 1.08109, 1.08686, 1.06286, ...
# 4  {2: (100, 1.08086, 1.08109, 1.08686, 1.06286, ...
#
#                                          open_shorts  \
# 0  {1: (100, 1.07786, 1.07777, 1.07486, 1.08686, ...
# 1  {1: (100, 1.07786, 1.07777, 1.07486, 1.08686, ...
# 2  {1: (100, 1.07786, 1.07777, 1.07486, 1.08686, ...
# 3  {1: (100, 1.07786, 1.07777, 1.07486, 1.08686, ...
# 4  {1: (100, 1.07786, 1.07777, 1.07486, 1.08686, ...
#
#                                         closed_longs  \
# 0                                                NaN
# 1  {1: (100, 1.07786, 1.07795, 0, {1.07486: 0, 1....
# 2                                                NaN
# 3  {6: (100, 1.07786, 1.07794, 0, {1.07486: 0, 1....
# 4  {3: (100, 1.08086, 1.08109, 0, {1.07786: 5, 1....
#
#                                        closed_shorts  \
# 0                                                NaN
# 1                                                NaN
# 2  {3: (100, 1.08086, 1.08092, 0, {1.08386: 0, 1....
# 3                                                NaN
# 4                                                NaN
#
#                            events  cum_long_position  cum_short_position  \
# 0                         ['ENT']              100.0               100.0
# 1            ['TP', 'COV', 'ENT']              200.0               200.0
# 2            ['TP', 'COV', 'ENT']              300.0               400.0
# 3            ['TP', 'COV', 'ENT']              600.0               500.0
# 4  ['PARUNL', 'TP', 'COV', 'ENT']             1000.0               600.0
#
#    open_long_count  open_short_count  closed_long_count  closed_short_count  \
# 0              1.0               1.0                0.0                 0.0
# 1              2.0               2.0                1.0                 0.0
# 2              3.0               4.0                0.0                 1.0
# 3              6.0               5.0                1.0                 0.0
# 4             10.0               6.0                2.0                 0.0
#
#    unrealised_pnl  realised_pnl   ac_bal  net_bal  margin_used  cash_bal  \
# 0           -0.02          0.00  5000.00  4999.98         6.67       NaN
# 1           -0.35          0.30  5000.30  4999.95        13.33       NaN
# 2           -0.69          0.30  5000.60  4999.91        23.33       NaN
# 3           -1.50          0.37  5000.97  4999.47        36.67       NaN
# 4           -1.94          0.71  5001.68  4999.74        53.33       NaN
#
#    gross_bal
# 0    5000.00
# 1    5000.30
# 2    5000.60
# 3    5000.97
# 4    5001.68

# %%
d.df['d'][d.df['d']['events'].str.contains('MC')].head()
# Out:
#                    time    mid_c    bid_c   ask_c open_longs open_shorts  \
# 48  2016-01-18 01:25:00  1.09062  1.09053  1.0907         {}          {}
#
#                                          closed_longs  \
# 48  {175: (100, 1.09586, 1.0964, 0, {1.09286: 4417...
#
#                                         closed_shorts  events  \
# 48  {464: (100, 1.08386, 1.08379, 0, {1.08686: 0, ...  ['MC']
#
#     cum_long_position  cum_short_position  open_long_count  open_short_count  \
# 48                0.0                 0.0              0.0               0.0
#
#     closed_long_count  closed_short_count  unrealised_pnl  realised_pnl  \
# 48             1798.0              2129.0             0.0      -1038.09
#
#      ac_bal  net_bal  margin_used  cash_bal  gross_bal
# 48  5362.15  5362.15          0.0       NaN    5362.15

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['gross_bal'])
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.show_plot()

# %%
d.df['d'].describe()
# Out:
#            mid_c      bid_c      ask_c  cum_long_position  cum_short_position  \
# count  88.000000  88.000000  88.000000          88.000000           88.000000
# mean    1.087789   1.087707   1.087870       21563.636364        24585.227273
# std     0.004349   0.004352   0.004347       36387.575819        42960.643683
# min     1.077860   1.077770   1.077940           0.000000            0.000000
# 25%     1.084143   1.084070   1.084215        1200.000000         1000.000000
# 50%     1.087640   1.087565   1.087710        6600.000000         4650.000000
# 75%     1.090580   1.090502   1.090650       27800.000000        27225.000000
# max     1.097790   1.097720   1.097860      179800.000000       212900.000000
#
#        open_long_count  open_short_count  closed_long_count  \
# count        88.000000         88.000000          88.000000
# mean        215.636364        245.852273          47.227273
# std         363.875758        429.606437         222.927736
# min           0.000000          0.000000           0.000000
# 25%          12.000000         10.000000           0.000000
# 50%          66.000000         46.500000           1.000000
# 75%         278.000000        272.250000           1.250000
# max        1798.000000       2129.000000        1798.000000
#
#        closed_short_count  unrealised_pnl  realised_pnl       ac_bal  \
# count           88.000000       88.000000     88.000000    88.000000
# mean            30.659091     -131.913068      7.063182  5314.573409
# std            228.256001      248.770820    136.338642   314.792518
# min              0.000000    -1187.960000  -1038.090000  5000.000000
# 25%              0.000000     -119.615000      0.262500  5046.795000
# 50%              1.000000      -31.435000      0.355000  5363.935000
# 75%              2.000000       -8.135000      1.310000  5410.540000
# max           2129.000000        0.000000    608.610000  6400.240000
#
#            net_bal   margin_used  cash_bal    gross_bal
# count    88.000000     88.000000       0.0    88.000000
# mean   5182.660341   1538.295227       NaN  5314.573409
# std     187.928637   2580.133278       NaN   314.792518
# min    4897.580000      0.000000       NaN  5000.000000
# 25%    4999.945000     70.000000       NaN  5046.795000
# 50%    5154.870000    390.000000       NaN  5363.935000
# 75%    5362.505000   1761.670000       NaN  5410.540000
# max    5452.800000  13090.000000       NaN  6400.240000

# %%
d.df['d'][d.df['d'].events.str.contains('MC')]
# Out:
#                    time    mid_c    bid_c   ask_c open_longs open_shorts  \
# 48  2016-01-18 01:25:00  1.09062  1.09053  1.0907         {}          {}
#
#                                          closed_longs  \
# 48  {175: (100, 1.09586, 1.0964, 0, {1.09286: 4417...
#
#                                         closed_shorts  events  \
# 48  {464: (100, 1.08386, 1.08379, 0, {1.08686: 0, ...  ['MC']
#
#     cum_long_position  cum_short_position  open_long_count  open_short_count  \
# 48                0.0                 0.0              0.0               0.0
#
#     closed_long_count  closed_short_count  unrealised_pnl  realised_pnl  \
# 48             1798.0              2129.0             0.0      -1038.09
#
#      ac_bal  net_bal  margin_used  cash_bal  gross_bal
# 48  5362.15  5362.15          0.0       NaN    5362.15

# %%
# my_cols = ['time', 'mid_c', 'bid_c', 'ask_c', 'events', 'cum_long_position',
#        'cum_short_position', 'open_long_count', 'open_short_count',
#        'closed_long_count', 'closed_short_count', 'unrealised_pnl',
#        'realised_pnl', 'ac_bal', 'net_bal', 'margin_used', 'cash_bal',
#        'gross_bal']
# d.df['d'][my_cols].to_csv(out_path + f'{ticker}-{freq}-{sim_no}-events-without-trades.csv', index=False)

# %%
d.df['d'].iloc[33:37]
# Out:
#                    time    mid_c    bid_c    ask_c  \
# 33  2016-01-13 14:35:00  1.08418  1.08411  1.08425
# 34  2016-01-13 15:30:00  1.08794  1.08785  1.08802
# 35  2016-01-13 15:50:00  1.08614  1.08605  1.08622
# 36  2016-01-14 08:50:00  1.09176  1.09168  1.09183
#
#                                            open_longs  \
# 33  {153: (100, 1.09286, 1.093, 1.09586, 1.07486, ...
# 34  {153: (100, 1.09286, 1.093, 1.09586, 1.07486, ...
# 35  {153: (100, 1.09286, 1.093, 1.09586, 1.07486, ...
# 36  {153: (100, 1.09286, 1.093, 1.09586, 1.07486, ...
#
#                                           open_shorts  \
# 33  {464: (100, 1.08386, 1.08379, 1.07786, 1.10186...
# 34  {464: (100, 1.08386, 1.08379, 1.07786, 1.10186...
# 35  {464: (100, 1.08386, 1.08379, 1.07786, 1.10186...
# 36  {464: (100, 1.08386, 1.08379, 1.07786, 1.10186...
#
#                                          closed_longs  \
# 33  {999: (100, 1.08086, 1.08084, 0, {1.07786: 0, ...
# 34  {846: (100, 1.08386, 1.08337, 0, {1.08086: 998...
# 35                                                NaN
# 36  {314: (100, 1.08686, 1.08753, 0, {1.08386: 503...
#
#                                         closed_shorts  \
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  {999: (100, 1.08086, 1.08071, 0, {1.08386: 115...
#
#                                   events  cum_long_position  \
# 33                  ['TP', 'COV', 'ENT']            43100.0
# 34        ['PARUNL', 'TP', 'COV', 'ENT']            71200.0
# 35                               ['COV']            71200.0
# 36  ['SL', 'PARUNL', 'TP', 'COV', 'ENT']            90600.0
#
#     cum_short_position  open_long_count  open_short_count  closed_long_count  \
# 33             40600.0            431.0             406.0                1.0
# 34             40700.0            712.0             407.0                2.0
# 35             52800.0            712.0             528.0                0.0
# 36             52800.0            906.0             528.0              182.0
#
#     closed_short_count  unrealised_pnl  realised_pnl   ac_bal  net_bal  \
# 33                 0.0         -196.56          0.33  5143.02  4946.46
# 34                 0.0         -190.26          0.81  5143.83  4953.57
# 35                 0.0         -246.25          0.00  5143.83  4897.58
# 36                 1.0         -271.72        124.78  5268.61  4996.89
#
#     margin_used  cash_bal  gross_bal
# 33      2790.00       NaN    5143.02
# 34      3730.00       NaN    5143.83
# 35      4133.33       NaN    5143.83
# 36      4780.00       NaN    5268.61

# %%
# i = 164
# total_pips = 0
# for trade_no, trade in d.to_dict_of_dicts('open_longs', OPEN_KEYS, i).items():
#     pips = round((d.fdata('ask_c',  i) - trade['ENT']) * pow(10, -d.ticker['pipLocation']), 1)
#     total_pips += pips
#     print(trade, pips)
# print(total_pips)

# %%
# i = 164
# total_pips = 0
# for trade_no, trade in d.to_dict_of_dicts('open_shorts', OPEN_KEYS, i).items():
#     pips = round((trade['ENT'] - d.fdata('bid_c',  i)) * pow(10, -d.ticker['pipLocation']), 1)
#     total_pips += pips
#     print(trade, pips)
# print(total_pips)
