# %%
from data import Data
import json
from plotting import CandlePlot
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
data_path = '../data/'
out_path = 'D:/Trading/ml4t-data/variable-grid/'
instruments = "../data/instruments.json"

# %%
OPEN_KEYS = ('SIZE', 'TRIG', 'ENT', 'TP', 'SL', 'TSL', 'PAR', 'COVS')
CLOSED_KEYS = ('SIZE', 'TRIG', 'ENT', 'PAR', 'COVS', 'EXIT', 'PIPS')

# %%
ticker = 'EUR_USD'
freq = 'M5'
sim_no = 50

# %%
results = pd.read_csv(out_path + f'{ticker}-{freq}-{sim_no}-events.csv')

# %%
d = Data(source=results, ticker=ticker, instruments=instruments)

# %%
# summary

# %%
d.prepare_fast_data('d')

# %%
d.df['d'].tail(5)
# Out:
#                     time    mid_c    bid_c    ask_c  \
# 227  2016-02-23 16:05:00  1.10349  1.10342  1.10356
# 228  2016-02-24 09:05:00  1.09834  1.09825  1.09842
# 229  2016-02-24 13:35:00  1.09930  1.09924  1.09937
# 230  2016-02-24 15:05:00  1.10256  1.10249  1.10263
# 231  2016-02-24 15:15:00  1.10336  1.10329  1.10342
#
#                                             open_longs  \
# 227  {129: (148, 1.11086, 1.11361, 1.11686, 1.08086...
# 228  {129: (148, 1.11086, 1.11361, 1.11686, 1.08086...
# 229  {129: (148, 1.11086, 1.11361, 1.11686, 1.08086...
# 230  {129: (148, 1.11086, 1.11361, 1.11686, 1.08086...
# 231  {129: (148, 1.11086, 1.11361, 1.11686, 1.08086...
#
#                                            open_shorts closed_longs  \
# 227  {130: (768, 1.10786, 1.11017, 1.09886, 1.13786...          NaN
# 228  {130: (768, 1.10786, 1.11017, 1.09586, 1.13786...          NaN
# 229  {131: (792, 1.10486, 1.10775, 1.09586, 1.13486...          NaN
# ...

# %%
d.df['d'].open_long_count.max(), d.df['d'].open_short_count.max()
# Out:
# (12.0, 25.0)

# %%
d.df['d'].margin_used.max()
# Out:
# 1901.8

# %%
d.df['d'][d.df['d']['events'].str.contains('MC')].head()
# Out:
#                     time    mid_c    bid_c    ask_c  \
# 104  2016-01-27 19:05:00  1.09103  1.09094  1.09112
# 170  2016-02-09 13:30:00  1.12666  1.12657  1.12675
#
#                                             open_longs  \
# 104  {63: (362, 1.09286, 1.09112, 1.09886, 1.06286,...
# 170  {105: (122, 1.12886, 1.12675, 1.13486, 1.09886...
#
#                                            open_shorts  \
# 104  {63: (1448, 1.09286, 1.09094, 1.08686, 1.12286...
# 170  {105: (491, 1.12886, 1.12657, 1.12286, 1.15886...
#
#                                           closed_longs  \
# 104  {9: (386, 1.09286, 1.09005, 1.09094, 10.7), 10...
# 170  {86: (196, 1.11986, 1.11698, 1.12657, 97.7), 8...
#
#                                          closed_shorts               events  \
# 104  {1: (1000, 1.08086, 1.07802, 1.09112, -129.2),...  ['UP', 'MC', 'ENT']
# 170  {76: (1732, 1.09586, 1.09314, 1.12675, -334.3)...  ['UP', 'MC', 'ENT']
#
# ...

# %%
d.df['d']['net_bal'] = d.df['d']['gross_bal'] - d.df['d']['unrealised_pnl']
d.df['d']['margin_call'] = d.df['d']['net_bal'] - d.df['d']['margin_used'] * 0.50

# %%
# d.df['d']['long_profits_ratio'] = d.df['d']['long_hist'].apply(eval).apply(sum) / (d.df['d']['long_hist'].apply(eval).apply(sum) + d.df['d']['short_hist'].apply(eval).apply(sum))
# d.df['d']['short_profits_ratio'] = d.df['d']['short_hist'].apply(eval).apply(sum) / (d.df['d']['long_hist'].apply(eval).apply(sum) + d.df['d']['short_hist'].apply(eval).apply(sum))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'long_hist'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[882], line 1
# ...

# %%
cp = CandlePlot(d.df['d'], candles=False)
# cp.add_traces(line_traces=['gross_bal', 'margin_used', 'margin_call'])
cp.add_traces(line_traces=['gross_bal'])
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.show_plot()

# %% [markdown]
# cp = CandlePlot(d.df['d'], candles=False)
# cp.add_traces(line_traces=['cum_short_position'], is_sec=True)
# cp.add_traces(line_traces=['up_moves_ratio', 'down_moves_ratio'])
# cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['gross_bal'], is_sec=True)
cp.add_traces(line_traces=['mid_c', 'long_profits_ratio'])
cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['gross_bal'], is_sec=True)
cp.add_traces(line_traces=['mid_c', 'short_profits_ratio'])
cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.add_traces(line_traces=['long_profits_ratio'])
cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.add_traces(line_traces=['short_profits_ratio'])
cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.add_traces(line_traces=['long_profits_ratio', 'short_profits_ratio'])
cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['cum_long_position'])
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['cum_short_position'])
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['gross_bal', 'margin_used', 'margin_call'])
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.show_plot()

# %%
cp = CandlePlot(d.df['d'], candles=False)
cp.add_traces(line_traces=['open_long_count', 'open_short_count'])
cp.add_traces(line_traces=['mid_c'], is_sec=True)
cp.show_plot()

# %%
d.df['d'].describe()
# Out:
#             mid_c       bid_c       ask_c  cum_long_position  \
# count  819.000000  819.000000  819.000000         819.000000
# mean     1.114038    1.113949    1.114127       10404.908425
# std      0.018029    0.018028    0.018030        5053.392561
# min      1.077860    1.077780    1.077940           0.000000
# 25%      1.099895    1.099810    1.099975        6786.000000
# 50%      1.114550    1.114430    1.114690        9646.000000
# 75%      1.128810    1.128715    1.128890       12928.000000
# max      1.159170    1.159100    1.159240       34640.000000
#
#        cum_short_position  open_long_count  open_short_count  \
# count          819.000000       819.000000        819.000000
# mean          2024.026862         8.521368          2.018315
# std           4822.655800         3.043767          4.620927
# min              0.000000         0.000000          0.000000
# 25%              0.000000         7.000000          0.000000
# ...

# %%
# my_cols = ['time', 'mid_c', 'bid_c', 'ask_c', 'events', 'cum_long_position',
#        'cum_short_position', 'open_long_count', 'open_short_count',
#        'closed_long_count', 'closed_short_count', 'unrealised_pnl',
#        'realised_pnl', 'ac_bal', 'net_bal', 'margin_used', 'cash_bal',
#        'gross_bal']
# d.df['d'][my_cols].to_csv(out_path + f'{ticker}-{freq}-{sim_no}-events-without-trades.csv', index=False)

# %%
# for trade_no, trade in eval(d.df['d'].iloc[328].open_shorts).items():
#     print(trade_no, trade[1])

# %%
# i = 164
# total_pips = 0
# for trade_no, trade in d.to_dict_of_dicts('open_longs', OPEN_KEYS, i).items():
#     pips = round((d.fdata('ask_c',  i) - trade['ENT']) * pow(10, -d.ticker['pipLocation']), 1)
#     total_pips += pips
#     print(trade, pips)
# print(total_pips)

# %%
# i = 164
# total_pips = 0
# for trade_no, trade in d.to_dict_of_dicts('open_shorts', OPEN_KEYS, i).items():
#     pips = round((trade['ENT'] - d.fdata('bid_c',  i)) * pow(10, -d.ticker['pipLocation']), 1)
#     total_pips += pips
#     print(trade, pips)
# print(total_pips)
