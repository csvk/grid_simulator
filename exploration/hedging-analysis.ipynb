# %%
import sys
sys.path.append("../")

# %%
import pandas as pd
import numpy as np
import datetime as dt
import math
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.offline import plot
from tqdm import tqdm
from tabulate import tabulate
import pickle as pkl
pd.set_option("display.max_columns", None)

# %%
class Data:
    
    def __init__(self, path):
        self.df = {
            'raw': pd.read_pickle(path)
        }
        if 'time' in self.df['raw'].columns:
            self.df['raw']['time'] = [ x.replace(tzinfo=None) for x in self.df['raw']['time']]

    def __repr__(self) -> str:
        repr = str()
        for name, df in self.df.items():
            repr = repr + name + ':\n' + str(df.head(3)) + '\n'
        return repr

    def shorten(self, name: str, rows: int, direction: int, source: str='raw', cols: list=None):
        '''Create new dataframe with specified list of columns and number of rows
        direction: 1 if data should be selected from top and -1 if from bottom
        '''
        assert (direction != 1 or direction != -1), 'direction must be 1 (top) or -1 (bottom)'
        
        if cols == None:
            cols = self.df[source].columns
        if direction == 1:
            self.df[name] = self.df[source][cols].iloc[:rows].copy()
        else:
            self.df[name] = self.df[source][cols].iloc[-rows:].copy()
        self.df[name].reset_index(drop=True, inplace=True)

    def add_columns(self, name: str, cols: list):
        '''Add new columns to component dataframes
        '''        
        exist_cols = list(self.df[name].columns)
        cols = exist_cols + cols
        self.df[name] = self.df[name].reindex(columns = cols) 

    def prepare_fast_data(self, name: str):
        '''Prepare data as an array for fast processing
        fcols = {col1: col1_index, col2: col2_index, .... }     
        fdata = [array[col1], array[col2], array[col3], .... ]
        Accessed by: self.fdata[fcols[column_name]] for whole column or
                     self.fdata[fcols[column_name]][row_index] for a specific row item
        '''
        self.fcols = dict()
        for i in range(len(self.df[name].columns)):
            self.fcols[self.df[name].columns[i]] = i
        self.fastdf = [self.df[name][col].array for col in self.df[name].columns]

    def fdata(self, column: str, index: int=-1):
        assert index >= -1, 'Row index cannot be negative'
        if index == -1:
            return self.fastdf[self.fcols[column]]
        else:
            return self.fastdf[self.fcols[column]][index]
        
    def update_fdata(self, column: str, value, index: int=-1):
        assert index >= -1, 'Row index cannot be negative'
        if index == -1:
            self.fastdf[self.fcols[column]] = value
        else:
            self.fastdf[self.fcols[column]][index] = value

# %%
PATH = 'D:/Trading/forex_bot/outputs/'

# %%
files = ['inputs4.pkl', 'inputs5.pkl', 'inputs6.pkl']

# %%
dfs = list()
for f in files:
    dfs.append(pd.read_pickle(PATH + f))

# %%
inputs = pd.concat(dfs)
inputs.drop_duplicates(inplace=True)
inputs.reset_index(drop=True,inplace=True)
inputs
# Out:
#     sim_name  init_signal  base_trade_size  cushion   risk  rr  \
# 0   sim_3001           -1               10      2.0  0.002   3
# 1   sim_3002           -1               10      2.0  0.003   3
# 2   sim_3003            1               10      2.0  0.004   3
# 3   sim_3004           -1               50      2.0  0.002   3
# 4   sim_3005           -1               50      2.0  0.003   3
# 5   sim_3006           -1               50      2.0  0.004   3
# 6   sim_3007            1              100      2.0  0.002   3
# 7   sim_3008            1              100      2.0  0.003   3
# 8   sim_3009            1              100      2.0  0.004   3
# 9   sim_4001            1               10      2.0  0.002   3
# 10  sim_4002            1               10      2.0  0.003   3
# 11  sim_4003            1               10      2.0  0.004   3
# 12  sim_4004            1               50      2.0  0.002   3
# 13  sim_4005           -1               50      2.0  0.003   3
# 14  sim_4006            1               50      2.0  0.004   3
# 15  sim_4007            1              100      2.0  0.002   3
# 16  sim_4008            1              100      2.0  0.003   3
# 17  sim_4009            1              100      2.0  0.004   3
# 18  sim_5001           -1               10      2.0  0.002   3
# 19  sim_5002           -1               10      2.0  0.003   3
# 20  sim_5003           -1               10      2.0  0.004   3
# 21  sim_5004           -1               50      2.0  0.002   3
# 22  sim_5005           -1               50      2.0  0.003   3
# 23  sim_5006           -1               50      2.0  0.004   3
# 24  sim_5007           -1              100      2.0  0.002   3
# 25  sim_5008           -1              100      2.0  0.003   3
# 26  sim_5009           -1              100      2.0  0.004   3
#
#     margin_closeout  streak_limit
# 0              True            11
# 1              True            11
# 2              True            11
# 3              True            11
# 4              True            11
# 5              True            11
# 6              True            11
# 7              True            11
# 8              True            11
# 9              True            12
# 10             True            12
# 11             True            12
# 12             True            12
# 13             True            12
# 14             True            12
# 15             True            12
# 16             True            12
# 17             True            12
# 18             True            13
# 19             True            13
# 20             True            13
# 21             True            13
# 22             True            13
# 23             True            13
# 24             True            13
# 25             True            13
# 26             True            13

# %%
inputs.to_pickle(PATH + 'inputs.n.all.pkl')

# %%
d = Data(PATH + "inputs.n.all.pkl")

# %%
subset = ['init_signal', 'base_trade_size', 'cushion', 'risk', 'rr', 'margin_closeout', 'streak_limit']
d.df['raw'].drop_duplicates(subset=subset, keep='first', inplace=True)
d.df['raw'].reset_index(drop=True, inplace=True)

# %%
cols = ['return_%', 'final_ac_bal', 'total_trades', 'avg_trade', 'avg_trade_duration', 'win_%', 'loss_%', 
        'expectancy', 'sharpe_ratio', 'sortino_ratio', 'calmar_ratio',
        'max_drawdown', 'max_ac_bal', 'min_ac_bal', 'max_margin_used', 'total_streaks', 'avg_trades_per_streak',
        'total_wins', 'max_win', 'avg_win', 'avg_win_duration', 'total_losses', 'max_loss', 'avg_loss', 'avg_loss_duration',
        'total_long', 'avg_long', 'avg_long_duration',
        'total_long_wins', 'avg_long_win', 'avg_long_win_duration',
        'total_long_losses', 'avg_long_loss', 'avg_long_loss_duration',
        'total_short', 'avg_short', 'avg_short_duration',
        'total_short_wins', 'avg_short_win', 'avg_short_win_duration',
        'total_short_losses', 'avg_short_loss', 'avg_short_loss_duration',
        
        ]
d.add_columns('raw', cols)
d.df['raw'].head(3)
# Out:
#    sim_name  init_signal  base_trade_size  cushion   risk  rr  \
# 0  sim_3001           -1               10      2.0  0.002   3
# 1  sim_3002           -1               10      2.0  0.003   3
# 2  sim_3003            1               10      2.0  0.004   3
#
#    margin_closeout  streak_limit  return_%  final_ac_bal  total_trades  \
# 0             True            11       NaN           NaN           NaN
# 1             True            11       NaN           NaN           NaN
# 2             True            11       NaN           NaN           NaN
#
#    avg_trade  avg_trade_duration  win_%  loss_%  expectancy  sharpe_ratio  \
# 0        NaN                 NaN    NaN     NaN         NaN           NaN
# 1        NaN                 NaN    NaN     NaN         NaN           NaN
# 2        NaN                 NaN    NaN     NaN         NaN           NaN
#
#    sortino_ratio  calmar_ratio  max_drawdown  max_ac_bal  min_ac_bal  \
# 0            NaN           NaN           NaN         NaN         NaN
# 1            NaN           NaN           NaN         NaN         NaN
# 2            NaN           NaN           NaN         NaN         NaN
#
#    max_margin_used  total_streaks  avg_trades_per_streak  total_wins  max_win  \
# 0              NaN            NaN                    NaN         NaN      NaN
# 1              NaN            NaN                    NaN         NaN      NaN
# 2              NaN            NaN                    NaN         NaN      NaN
#
#    avg_win  avg_win_duration  total_losses  max_loss  avg_loss  \
# 0      NaN               NaN           NaN       NaN       NaN
# 1      NaN               NaN           NaN       NaN       NaN
# 2      NaN               NaN           NaN       NaN       NaN
#
#    avg_loss_duration  total_long  avg_long  avg_long_duration  \
# 0                NaN         NaN       NaN                NaN
# 1                NaN         NaN       NaN                NaN
# 2                NaN         NaN       NaN                NaN
#
#    total_long_wins  avg_long_win  avg_long_win_duration  total_long_losses  \
# 0              NaN           NaN                    NaN                NaN
# 1              NaN           NaN                    NaN                NaN
# 2              NaN           NaN                    NaN                NaN
#
#    avg_long_loss  avg_long_loss_duration  total_short  avg_short  \
# 0            NaN                     NaN          NaN        NaN
# 1            NaN                     NaN          NaN        NaN
# 2            NaN                     NaN          NaN        NaN
#
#    avg_short_duration  total_short_wins  avg_short_win  \
# 0                 NaN               NaN            NaN
# 1                 NaN               NaN            NaN
# 2                 NaN               NaN            NaN
#
#    avg_short_win_duration  total_short_losses  avg_short_loss  \
# 0                     NaN                 NaN             NaN
# 1                     NaN                 NaN             NaN
# 2                     NaN                 NaN             NaN
#
#    avg_short_loss_duration
# 0                      NaN
# 1                      NaN
# 2                      NaN

# %%
d.prepare_fast_data('raw')

# %%
d.fdata('sim_name', 0)
# Out:
# 'sim_3001'

# %%
def convert2date(date_time):
    return date_time.date().strftime("%Y-%m-%d")

# %%
def sharpe_ratio(returns: pd.Series, risk_free_rate: float=0) -> float:
    return (returns.mean() - risk_free_rate) / returns.std()

def sortino_ratio(returns: pd.Series, risk_free_rate: float=0, target_return: float=0) -> float:
    downside_returns = np.array([ret - risk_free_rate for ret in returns if ret < target_return])
    std_dev_downside = np.std(downside_returns, ddof=1) if len(downside_returns) > 0 else 0
    return (np.mean(returns) - risk_free_rate) / std_dev_downside if std_dev_downside != 0 else np.nan

def max_drawdown(returns: pd.Series) -> float:
    '''
    cum_returns: Calculates the cumulative returns using np.cumprod(1 + returns).
    peaks: Finds the peaks in the cumulative returns using np.maximum.accumulate(cum_returns).
    drawdowns: Calculates the drawdowns for each point by subtracting the peaks from the cumulative returns and dividing by the peaks.
    max_drawdown: Identifies the maximum drawdown by finding the minimum drawdown value using np.min(drawdowns).'''
    cum_returns = np.cumprod(1 + returns.values)
    peaks = np.maximum.accumulate(cum_returns)
    drawdowns = (cum_returns - peaks) / peaks
    max_drawdown = np.min(drawdowns)
    return max_drawdown

def calmar_ratio(returns: pd.Series, risk_free_rate: float=0):
    max_drawdown_value = max_drawdown(returns)
    annual_return = np.mean(returns) * 311  # Assuming 311 trading days per year for forex. Its usually 252 for stocks
    return annual_return / abs(max_drawdown_value)

# %%
def populate_results(d: Data, i: int, df: pd.DataFrame):
    d.update_fdata('return_%', (df['ac_bal'].iloc[-1] - df['ac_bal'].iloc[0]) / df['ac_bal'].iloc[0], i)
    d.update_fdata('final_ac_bal', df['ac_bal'].iloc[-1], i)
    d.update_fdata('max_ac_bal', df['ac_bal'].max(), i)
    d.update_fdata('min_ac_bal', df['ac_bal'].min(), i)
    d.update_fdata('max_margin_used', df['margin_used'].max(), i)
    d.update_fdata('total_streaks', df['streak_no'].iloc[-1], i)
    d.update_fdata('avg_trades_per_streak', df.groupby('streak_no')['trade_no'].max().mean(), i)
    
    trades = df[df.signal != 0].copy()
    trades['return'] = trades['ac_bal'].shift(-1) - trades['ac_bal']
    trades['return_%'] = trades['ac_bal'].pct_change().shift(-1)
    trades['index'] = trades.index
    trades['duration'] = trades['index'].shift(-1) - trades['index']
    trades.dropna(inplace=True)
    # print(trades[['ac_bal', 'return', 'return_%']].head())

    d.update_fdata('sharpe_ratio', sharpe_ratio(trades['return_%']), i)
    d.update_fdata('sortino_ratio', sortino_ratio(trades['return_%']), i)
    d.update_fdata('calmar_ratio', calmar_ratio(trades['return_%']), i)
    d.update_fdata('max_drawdown', max_drawdown(trades['return_%']), i)

    d.update_fdata('total_trades', trades.shape[0], i)
    d.update_fdata('avg_trade', trades['return'].mean(), i)
    d.update_fdata('avg_trade_duration', trades['duration'].mean(), i)
    
    wins = trades[trades['return'] > 0]
    d.update_fdata('total_wins', wins.shape[0], i)
    d.update_fdata('max_win', wins['return'].max(), i)
    d.update_fdata('avg_win', wins['return'].mean(), i)
    d.update_fdata('avg_win_duration', wins['duration'].mean(), i)
    d.update_fdata('win_%', d.fdata('total_wins', i) / d.fdata('total_trades', i), i)

    losses = trades[trades['return'] < 0]
    d.update_fdata('total_losses', losses.shape[0], i)
    d.update_fdata('max_loss', losses['return'].min(), i)
    d.update_fdata('avg_loss', losses['return'].mean(), i)
    d.update_fdata('avg_loss_duration', losses['duration'].mean(), i)
    d.update_fdata('loss_%', d.fdata('total_losses', i) / d.fdata('total_trades', i), i)
    
    longs = trades[trades.signal == 1]
    d.update_fdata('total_long', longs.shape[0], i)
    d.update_fdata('avg_long', longs['return'].mean(), i)
    d.update_fdata('avg_long_duration', longs['duration'].mean(), i)

    long_wins = longs[longs['return'] > 0]
    d.update_fdata('total_long_wins', long_wins.shape[0], i)
    d.update_fdata('avg_long_win', long_wins['return'].mean(), i)
    d.update_fdata('avg_long_win_duration', long_wins['duration'].mean(), i)

    long_losses = longs[longs['return'] < 0]
    d.update_fdata('total_long_losses', long_losses.shape[0], i)
    d.update_fdata('avg_long_loss', long_losses['return'].mean(), i)
    d.update_fdata('avg_long_loss_duration', long_losses['duration'].mean(), i)

    shorts = trades[trades.signal == -1]
    d.update_fdata('total_short', shorts.shape[0], i)
    d.update_fdata('avg_short', shorts['return'].mean(), i)
    d.update_fdata('avg_short_duration', shorts['duration'].mean(), i)

    short_wins = shorts[shorts['return'] > 0]
    d.update_fdata('total_short_wins', short_wins.shape[0], i)
    d.update_fdata('avg_short_win', short_wins['return'].mean(), i)
    d.update_fdata('avg_short_win_duration', short_wins['duration'].mean(), i)

    short_losses = shorts[shorts['return'] < 0]
    d.update_fdata('total_short_losses', short_losses.shape[0], i)
    d.update_fdata('avg_short_loss', short_losses['return'].mean(), i)
    d.update_fdata('avg_short_loss_duration', short_losses['duration'].mean(), i)


    d.update_fdata('expectancy', d.fdata('win_%', i) * d.fdata('avg_win', i) + d.fdata('loss_%', i) * d.fdata('avg_loss', i), i)

# %%
sims = d.df['raw'].shape[0]
for i in tqdm(range(sims), desc=" Analysing... "):
# for i in tqdm(range(2), desc=" Analysing... "):
    data = pd.read_pickle(PATH + d.fdata('sim_name', i) + '.pkl')
    assert (d.fdata('sim_name', i) == data['sim_name'] and
            d.fdata('init_signal', i) == data['init_signal'] and
            d.fdata('base_trade_size', i) == data['base_trade_size'] and
            d.fdata('cushion', i) == data['cushion'] and
            d.fdata('risk', i) == data['risk'] and
            d.fdata('rr', i) == data['rr'] and
            d.fdata('margin_closeout', i) == data['margin_closeout'] and
            d.fdata('streak_limit', i) == data['streak_limit']), f"Parameters mismatch for {d.fdata('sim_name', i)}"
    
    populate_results(d, i, data['results'])
# Out:
#  Analysing... : 100%|██████████| 27/27 [00:03<00:00,  7.05it/s]

# %%
data
# Out:
# {'sim_name': 'sim_5009',
#  'init_signal': -1,
#  'base_trade_size': 100,
#  'cushion': 2.0,
#  'risk': 0.004,
#  'rr': 3,
#  'margin_closeout': True,
#  'streak_limit': 13,
#  'results':                       time    bid_o    bid_h    bid_l    bid_c    ask_o  \
#  0      2016-01-07 00:00:00  1.07757  1.07802  1.07750  1.07777  1.07772
#  1      2016-01-07 00:05:00  1.07779  1.07811  1.07755  1.07802  1.07798
#  2      2016-01-07 00:10:00  1.07803  1.07823  1.07803  1.07819  1.07822
#  3      2016-01-07 00:15:00  1.07815  1.07821  1.07790  1.07790  1.07834
#  4      2016-01-07 00:20:00  1.07787  1.07789  1.07768  1.07782  1.07804
#  ...                    ...      ...      ...      ...      ...      ...
#  594298 2023-12-29 21:35:00  1.10355  1.10374  1.10355  1.10371  1.10374
#  594299 2023-12-29 21:40:00  1.10370  1.10379  1.10356  1.10371  1.10388
#  594300 2023-12-29 21:45:00  1.10371  1.10384  1.10371  1.10378  1.10388
#  594301 2023-12-29 21:50:00  1.10379  1.10389  1.10375  1.10383  1.10393
#  594302 2023-12-29 21:55:00  1.10382  1.10388  1.10346  1.10363  1.10401
#
#            ask_h    ask_l    ask_c    mid_c  signal  streak_no  trade_no  \
#  0       1.07820  1.07768  1.07795  1.07786    -1.0        1.0       1.0
#  1       1.07827  1.07772  1.07819  1.07810     0.0        1.0       1.0
#  2       1.07840  1.07822  1.07837  1.07828     0.0        1.0       1.0
#  3       1.07838  1.07807  1.07807  1.07798     0.0        1.0       1.0
#  4       1.07809  1.07784  1.07797  1.07790     0.0        1.0       1.0
#  ...         ...      ...      ...      ...     ...        ...       ...
#  594298  1.10391  1.10374  1.10387  1.10379     0.0      301.0       2.0
#  594299  1.10396  1.10372  1.10387  1.10379     0.0      301.0       2.0
#  594300  1.10398  1.10387  1.10392  1.10385     0.0      301.0       2.0
#  594301  1.10407  1.10389  1.10401  1.10392     0.0      301.0       2.0
#  594302  1.10406  1.10381  1.10386  1.10374     0.0      301.0       2.0
#
#          position_size  cum_position_size  buy_price  sell_price  buy_tp_price  \
#  0               100.0              100.0    1.08168     1.07768       1.09368
#  1               100.0              100.0    1.08168     1.07768       1.09368
#  2               100.0              100.0    1.08168     1.07768       1.09368
#  3               100.0              100.0    1.08168     1.07768       1.09368
#  4               100.0              100.0    1.08168     1.07768       1.09368
#  ...               ...                ...        ...         ...           ...
#  594298           67.0              167.0    1.11133     1.10733       1.12333
#  594299           67.0              167.0    1.11133     1.10733       1.12333
#  594300           67.0              167.0    1.11133     1.10733       1.12333
#  594301           67.0              167.0    1.11133     1.10733       1.12333
#  594302           67.0              167.0    1.11133     1.10733       1.12333
#
#          sell_tp_price  unrealised_pl  realised_pl      ac_bal  margin_used  \
#  0             1.06568       -0.01800         0.00  1000.00000     3.333333
#  1             1.06568       -0.04200         0.00  1000.00000     3.333333
#  2             1.06568       -0.06000         0.00  1000.00000     3.333333
#  3             1.06568       -0.03000         0.00  1000.00000     3.333333
#  4             1.06568       -0.02200         0.00  1000.00000     3.333333
#  ...               ...            ...          ...         ...          ...
#  594298        1.09533        0.23718        -0.41  1038.97126     2.233333
#  594299        1.09533        0.23718        -0.41  1038.97126     2.233333
#  594300        1.09533        0.23316        -0.41  1038.97126     2.233333
#  594301        1.09533        0.22847        -0.41  1038.97126     2.233333
#  594302        1.09533        0.24053        -0.41  1038.97126     2.233333
#
#          margin_closeout
#  0             999.98200
#  1             999.95800
#  2             999.94000
#  3             999.97000
#  4             999.97800
#  ...                 ...
#  594298       1039.20844
#  594299       1039.20844
#  594300       1039.20442
#  594301       1039.19973
#  594302       1039.21179
#
#  [594303 rows x 24 columns]}

# %%
with open(PATH + 'hedging_sim_analysis.n.pkl', 'wb') as file:
    pkl.dump(d.df['raw'], file)

# %%
d.df['raw'].head()
# Out:
#    sim_name  init_signal  base_trade_size  cushion   risk  rr  \
# 0  sim_3001           -1               10      2.0  0.002   3
# 1  sim_3002           -1               10      2.0  0.003   3
# 2  sim_3003            1               10      2.0  0.004   3
# 3  sim_3004           -1               50      2.0  0.002   3
# 4  sim_3005           -1               50      2.0  0.003   3
#
#    margin_closeout  streak_limit  return_%  final_ac_bal  total_trades  \
# 0             True            11 -0.057775     942.22454        4968.0
# 1             True            11 -0.079735     920.26476        2273.0
# 2             True            11  0.005429    1005.42937        1275.0
# 3             True            11 -0.275124     724.87579        4968.0
# 4             True            11 -0.378302     621.69840        2273.0
#
#    avg_trade  avg_trade_duration     win_%    loss_%  expectancy  \
# 0  -0.011630          119.554750  0.215781  0.784219   -0.011630
# 1  -0.035079          261.448306  0.229212  0.770788   -0.035079
# 2   0.004258          465.818039  0.227451  0.772549    0.004258
# 3  -0.055379          119.554750  0.215781  0.784219   -0.055379
# 4  -0.166433          261.448306  0.229212  0.770788   -0.166433
#
#    sharpe_ratio  sortino_ratio  calmar_ratio  max_drawdown  max_ac_bal  \
# 0     -0.021480      -0.039517     -0.051915     -0.070854  1002.22034
# 1     -0.056697      -0.086416     -0.129449     -0.087333  1000.08492
# 2      0.004840       0.009181      0.039667     -0.037013  1037.67452
# 3     -0.019359      -0.036196     -0.055864     -0.334055  1010.42282
# 4     -0.055288      -0.084468     -0.152067     -0.414005  1000.38772
#
#    min_ac_bal  max_margin_used  total_streaks  avg_trades_per_streak  \
# 0   931.20928        23.600000         1133.0               4.385702
# 1   912.74466        23.600000          553.0               4.112116
# 2   979.22459        23.600000          304.0               4.197368
# 3   672.88611       111.566667         1133.0               4.385702
# 4   586.22174       111.566667          553.0               4.112116
#
#    total_wins   max_win   avg_win  avg_win_duration  total_losses  max_loss  \
# 0      1072.0   8.79336  0.424225        223.084888        3896.0  -3.57540
# 1       521.0   7.50480  0.440882        441.865643        1752.0  -4.09224
# 2       290.0   9.01992  0.795488        770.944828         985.0  -7.35612
# 3      1072.0  41.56974  2.008414        223.084888        3896.0 -16.90235
# 4       521.0  35.47820  2.088745        441.865643        1752.0 -19.34566
#
#    avg_loss  avg_loss_duration  total_long  avg_long  avg_long_duration  \
# 0 -0.131557          91.068018      2483.0 -0.002535         114.602094
# 1 -0.176618         207.796804      1138.0 -0.012442         248.965729
# 2 -0.228693         375.983756       638.0  0.027306         431.800940
# 3 -0.623240          91.068018      2483.0 -0.012493         114.602094
# 4 -0.837065         207.796804      1138.0 -0.059510         248.965729
#
#    total_long_wins  avg_long_win  avg_long_win_duration  total_long_losses  \
# 0            535.0      0.458308             209.887850             1948.0
# 1            262.0      0.543101             421.377863              876.0
# 2            145.0      0.880302             713.179310              493.0
# 3            535.0      2.169178             209.887850             1948.0
# 4            262.0      2.571627             421.377863              876.0
#
#    avg_long_loss  avg_long_loss_duration  total_short  avg_short  \
# 0      -0.129101               88.432752       2485.0  -0.020717
# 1      -0.178598              197.399543       1135.0  -0.057776
# 2      -0.223575              349.042596        637.0  -0.018825
# 3      -0.611668               88.432752       2485.0  -0.098231
# 4      -0.846449              197.399543       1135.0  -0.273638
#
#    avg_short_duration  total_short_wins  avg_short_win  \
# 0          124.503421             537.0       0.390268
# 1          273.963877             259.0       0.337478
# 2          499.888540             145.0       0.710674
# 3          124.503421             537.0       1.848248
# 4          273.963877             259.0       1.600269
#
#    avg_short_win_duration  total_short_losses  avg_short_loss  \
# 0              236.232775              1948.0       -0.134012
# 1              462.590734               876.0       -0.174638
# 2              828.710345               492.0       -0.233820
# 3              236.232775              1948.0       -0.634812
# 4              462.590734               876.0       -0.827681
#
#    avg_short_loss_duration
# 0                93.703285
# 1               218.194064
# 2               402.979675
# 3                93.703285
# 4               218.194064

# %%
with open(PATH + 'hedging_sim_analysis.n.pkl', 'rb') as f:
    df_all = pkl.load(f)

# %%
df_all.drop_duplicates(subset=['init_signal', 'base_trade_size', 'cushion', 'risk', 'rr', 'margin_closeout', 'streak_limit'],keep='first')
df_all
# Out:
#     sim_name  init_signal  base_trade_size  cushion   risk  rr  \
# 0   sim_3001           -1               10      2.0  0.002   3
# 1   sim_3002           -1               10      2.0  0.003   3
# 2   sim_3003            1               10      2.0  0.004   3
# 3   sim_3004           -1               50      2.0  0.002   3
# 4   sim_3005           -1               50      2.0  0.003   3
# 5   sim_3006           -1               50      2.0  0.004   3
# 6   sim_3007            1              100      2.0  0.002   3
# 7   sim_3008            1              100      2.0  0.003   3
# 8   sim_3009            1              100      2.0  0.004   3
# 9   sim_4001            1               10      2.0  0.002   3
# 10  sim_4002            1               10      2.0  0.003   3
# 11  sim_4003            1               10      2.0  0.004   3
# 12  sim_4004            1               50      2.0  0.002   3
# 13  sim_4005           -1               50      2.0  0.003   3
# 14  sim_4006            1               50      2.0  0.004   3
# 15  sim_4007            1              100      2.0  0.002   3
# 16  sim_4008            1              100      2.0  0.003   3
# 17  sim_4009            1              100      2.0  0.004   3
# 18  sim_5001           -1               10      2.0  0.002   3
# 19  sim_5002           -1               10      2.0  0.003   3
# 20  sim_5003           -1               10      2.0  0.004   3
# 21  sim_5004           -1               50      2.0  0.002   3
# 22  sim_5005           -1               50      2.0  0.003   3
# 23  sim_5006           -1               50      2.0  0.004   3
# 24  sim_5007           -1              100      2.0  0.002   3
# 25  sim_5008           -1              100      2.0  0.003   3
# 26  sim_5009           -1              100      2.0  0.004   3
#
#     margin_closeout  streak_limit  return_%  final_ac_bal  total_trades  \
# 0              True            11 -0.057775     942.22454        4968.0
# 1              True            11 -0.079735     920.26476        2273.0
# 2              True            11  0.005429    1005.42937        1275.0
# 3              True            11 -0.275124     724.87579        4968.0
# 4              True            11 -0.378302     621.69840        2273.0
# 5              True            11  0.133203    1133.20294        1273.0
# 6              True            11 -0.546863     453.13743        4965.0
# 7              True            11 -0.688197     311.80338        2268.0
# 8              True            11  0.048810    1048.80982        1275.0
# 9              True            12 -0.059178     940.82190        4965.0
# 10             True            12 -0.103738     896.26157        2268.0
# 11             True            12 -0.024241     975.75904        1275.0
# 12             True            12 -0.281705     718.29521        4965.0
# 13             True            12 -0.541410     458.58994        2273.0
# 14             True            12 -0.115492     884.50778        1275.0
# 15             True            12 -0.560063     439.93739        4965.0
# 16             True            12 -0.977147      22.85288        2268.0
# 17             True            12 -0.229637     770.36298        1275.0
# 18             True            13 -0.067748     932.25219        4968.0
# 19             True            13 -0.151759     848.24109        2273.0
# 20             True            13  0.004374    1004.37352        1273.0
# 21             True            13 -0.322190     677.80965        4968.0
# 22             True            13 -0.718645     281.35490        2273.0
# 23             True            13  0.019695    1019.69493        1273.0
# 24             True            13 -0.640462     359.53844        4968.0
# 25             True            13 -1.427978    -427.97755        2273.0
# 26             True            13  0.038971    1038.97126        1273.0
#
#     avg_trade  avg_trade_duration     win_%    loss_%  expectancy  \
# 0   -0.011630          119.554750  0.215781  0.784219   -0.011630
# 1   -0.035079          261.448306  0.229212  0.770788   -0.035079
# 2    0.004258          465.818039  0.227451  0.772549    0.004258
# 3   -0.055379          119.554750  0.215781  0.784219   -0.055379
# 4   -0.166433          261.448306  0.229212  0.770788   -0.166433
# 5    0.104637          466.549882  0.230165  0.769835    0.104637
# 6   -0.110144          119.626989  0.215911  0.784089   -0.110144
# 7   -0.303438          262.024691  0.230600  0.769400   -0.303438
# 8    0.038282          465.818039  0.227451  0.772549    0.038282
# 9   -0.011919          119.626989  0.215911  0.784089   -0.011919
# 10  -0.045740          262.024691  0.230600  0.769400   -0.045740
# 11  -0.019013          465.818039  0.227451  0.772549   -0.019013
# 12  -0.056738          119.626989  0.215911  0.784089   -0.056738
# 24              236.232775              1948.0       -1.953368
# 25              462.590734               876.0       -2.741190
# 26              815.034014               490.0       -3.092640
#
#     avg_short_loss_duration
# 0                 93.703285
# 1                218.194064
# 2                402.979675
# 3                 93.703285
# 4                218.194064
# 5                408.222449
# 6                 93.845838
# 7                218.496560
# 8                402.979675
# 9                 93.845838
# 10               218.496560
# 11               402.979675
# 12                93.845838
# 13               218.194064
# 14               402.979675
# 15                93.845838
# 16               218.496560
# 17               402.979675
# 18                93.703285
# 19               218.194064
# 20               408.222449
# 21                93.703285
# 22               218.194064
# 23               408.222449
# 24                93.703285
# 25               218.194064
# 26               408.222449

# %%
df = df_all[df_all.margin_closeout == True].copy()
df.reset_index(inplace=True)
df
# Out:
#     index  sim_name  init_signal  base_trade_size  cushion   risk  rr  \
# 0       0  sim_3001           -1               10      2.0  0.002   3
# 1       1  sim_3002           -1               10      2.0  0.003   3
# 2       2  sim_3003            1               10      2.0  0.004   3
# 3       3  sim_3004           -1               50      2.0  0.002   3
# 4       4  sim_3005           -1               50      2.0  0.003   3
# 5       5  sim_3006           -1               50      2.0  0.004   3
# 6       6  sim_3007            1              100      2.0  0.002   3
# 7       7  sim_3008            1              100      2.0  0.003   3
# 8       8  sim_3009            1              100      2.0  0.004   3
# 9       9  sim_4001            1               10      2.0  0.002   3
# 10     10  sim_4002            1               10      2.0  0.003   3
# 11     11  sim_4003            1               10      2.0  0.004   3
# 12     12  sim_4004            1               50      2.0  0.002   3
# 13     13  sim_4005           -1               50      2.0  0.003   3
# 14     14  sim_4006            1               50      2.0  0.004   3
# 15     15  sim_4007            1              100      2.0  0.002   3
# 16     16  sim_4008            1              100      2.0  0.003   3
# 17     17  sim_4009            1              100      2.0  0.004   3
# 18     18  sim_5001           -1               10      2.0  0.002   3
# 19     19  sim_5002           -1               10      2.0  0.003   3
# 20     20  sim_5003           -1               10      2.0  0.004   3
# 21     21  sim_5004           -1               50      2.0  0.002   3
# 22     22  sim_5005           -1               50      2.0  0.003   3
# 23     23  sim_5006           -1               50      2.0  0.004   3
# 24     24  sim_5007           -1              100      2.0  0.002   3
# 25     25  sim_5008           -1              100      2.0  0.003   3
# 26     26  sim_5009           -1              100      2.0  0.004   3
#
#     margin_closeout  streak_limit  return_%  final_ac_bal  total_trades  \
# 0              True            11 -0.057775     942.22454        4968.0
# 1              True            11 -0.079735     920.26476        2273.0
# 2              True            11  0.005429    1005.42937        1275.0
# 3              True            11 -0.275124     724.87579        4968.0
# 4              True            11 -0.378302     621.69840        2273.0
# 5              True            11  0.133203    1133.20294        1273.0
# 6              True            11 -0.546863     453.13743        4965.0
# 7              True            11 -0.688197     311.80338        2268.0
# 8              True            11  0.048810    1048.80982        1275.0
# 9              True            12 -0.059178     940.82190        4965.0
# 10             True            12 -0.103738     896.26157        2268.0
# 11             True            12 -0.024241     975.75904        1275.0
# 12             True            12 -0.281705     718.29521        4965.0
# 13             True            12 -0.541410     458.58994        2273.0
# 14             True            12 -0.115492     884.50778        1275.0
# 15             True            12 -0.560063     439.93739        4965.0
# 16             True            12 -0.977147      22.85288        2268.0
# 12     -0.012862      -0.023736     -0.046553     -0.380718  1031.16779
# 13     -0.051179      -0.079063     -0.173742     -0.578860  1000.38772
# 14     -0.013209      -0.022094     -0.100239     -0.244318  1162.34006
# 15     -0.007247      -0.013871     -0.038455     -0.734779  1061.89481
# 16      0.017715       0.181360     58.183787     -1.048988  1046.03079
# 17     -0.010609      -0.017782     -0.095329     -0.426696  1322.39290
# 18     -0.012222      -0.021449     -0.050363     -0.083439  1005.10176
# 19     -0.044078      -0.070970     -0.124722     -0.177330  1000.08492
# 20      0.002868       0.005251      0.022381     -0.067261  1054.65027
# 21     -0.009663      -0.017233     -0.047817     -0.387968  1022.52852
# 22     -0.021576      -0.042138     -0.149692     -0.839217  1000.38772
# 23      0.005706       0.010993      0.051965     -0.266632  1257.27489
# 24     -0.003371      -0.006278     -0.024646     -0.754679  1044.55628
# 25      0.012060       0.024042      2.838648     -1.666915  1000.75996
# 26      0.008972       0.018491      0.097600     -0.440792  1510.93299
#
#     min_ac_bal  max_margin_used  total_streaks  avg_trades_per_streak  \
# 0    931.20928        23.600000         1133.0               4.385702
# 1    912.74466        23.600000          553.0               4.112116
# 2    979.22459        23.600000          304.0               4.197368
# 3    672.88611       111.566667         1133.0               4.385702
# 4    586.22174       111.566667          553.0               4.112116
# 5    987.39336       111.566667          305.0               4.177049
# 6    349.85108       221.666667         1133.0               4.383054
# 7    241.32081       221.666667          554.0               4.095668
# 8    804.81486       221.666667          304.0               4.197368
# 9    923.93081        39.333333         1117.0               4.445837
# 10   888.37293        39.333333          548.0               4.140511
# 11   966.36314        39.333333          302.0               4.225166
# 12   638.58396       185.933333         1117.0               4.445837
# 13   421.30364       185.933333          547.0               4.157221
# 14   840.98215       185.933333          302.0               4.225166
# 15   281.63637       369.433333         1117.0               4.445837
# 16   -51.24293       369.433333          548.0               4.140511
# 17   684.04177       369.433333          302.0               4.225166
# 18   921.23693        65.566667         1105.0               4.496833
# 19   822.73945        65.566667          542.0               4.195572
# 20   983.71348        65.566667          301.0               4.232558
# 21   625.81997       309.900000         1105.0               4.496833
# 22   160.84560       309.900000          542.0               4.195572
# 23   922.04526       309.900000          301.0               4.232558
# 24   256.25209       615.733333         1105.0               4.496833
# 25  -667.42136       615.733333          542.0               4.195572
# 26   844.92636       615.733333          301.0               4.232558
#
#     total_wins    max_win    avg_win  avg_win_duration  total_losses  \
# 0       1072.0    8.79336   0.424225        223.084888        3896.0
# 1        521.0    7.50480   0.440882        441.865643        1752.0
# 2        290.0    9.01992   0.795488        770.944828         985.0
# 3       1072.0   41.56974   2.008414        223.084888        3896.0
# 4        521.0   35.47820   2.088745        441.865643        1752.0
# 5        293.0   42.64078   3.749820        767.737201         980.0
# 6       1072.0   82.59300   3.984728        222.981343        3893.0
# 7        523.0   70.49000   4.186368        441.541109        1745.0
# 8        290.0   84.72100   7.483118        770.944828         985.0
# 9       1072.0   15.43440   0.537862        222.981343        3893.0
# 10       523.0   12.44900   0.558829        441.541109        1745.0
# 11       290.0   15.34000   0.886520        770.944828         985.0
# 12      1072.0   72.96024   2.545558        222.981343        3893.0
# 18  -0.015897          124.503421             537.0       0.679859
# 19  -0.069030          273.963877             259.0       0.683061
# 20  -0.059614          502.102041             147.0       0.837398
# 21  -0.075472          124.503421             537.0       3.216824
# 22  -0.326786          273.963877             259.0       3.233824
# 23  -0.282065          502.102041             147.0       3.965505
# 24  -0.150034          124.503421             537.0       6.391669
# 25  -0.649235          273.963877             259.0       6.426256
# 26  -0.560538          502.102041             147.0       7.879803
#
#     avg_short_win_duration  total_short_losses  avg_short_loss  \
# 0               236.232775              1948.0       -0.134012
# 1               462.590734               876.0       -0.174638
# 2               828.710345               492.0       -0.233820
# 3               236.232775              1948.0       -0.634812
# 4               462.590734               876.0       -0.827681
# 5               815.034014               490.0       -0.996544
# 6               235.970205              1946.0       -1.259854
# 7               462.753846               872.0       -1.638879
# 8               828.710345               492.0       -2.201366
# 9               235.970205              1946.0       -0.165417
# 10              462.753846               872.0       -0.229738
# 11              828.710345               492.0       -0.291844
# 12              235.970205              1946.0       -0.783259
# 13              462.590734               876.0       -1.109073
# 14              828.710345               492.0       -1.382034
# 15              235.970205              1946.0       -1.556394
# 16              462.753846               872.0       -2.162202
# 17              828.710345               492.0       -2.746289
# 18              236.232775              1948.0       -0.207694
# 19              462.590734               876.0       -0.291395
# 20              815.034014               490.0       -0.328718
# 21              236.232775              1948.0       -0.983051
# 22              462.590734               876.0       -1.379524
# 23              815.034014               490.0       -1.556336
# 24              236.232775              1948.0       -1.953368
# 25              462.590734               876.0       -2.741190
# 26              815.034014               490.0       -3.092640
#
#     avg_short_loss_duration
# 0                 93.703285
# 1                218.194064
# 2                402.979675
# 3                 93.703285
# 4                218.194064
# 5                408.222449
# 6                 93.845838
# 7                218.496560
# 8                402.979675
# 9                 93.845838
# 10               218.496560
# 11               402.979675
# 12                93.845838
# 13               218.194064
# 14               402.979675
# 15                93.845838
# 16               218.496560
# 17               402.979675
# 18                93.703285
# 19               218.194064
# 20               408.222449
# 21                93.703285
# 22               218.194064
# 23               408.222449
# 24                93.703285
# 25               218.194064
# 26               408.222449

# %%
df0 = df_all[df_all.margin_closeout == False].copy()
df0.reset_index(inplace=True)
df0
# Out:
# Empty DataFrame
# Columns: [index, sim_name, init_signal, base_trade_size, cushion, risk, rr, margin_closeout, streak_limit, return_%, final_ac_bal, total_trades, avg_trade, avg_trade_duration, win_%, loss_%, expectancy, sharpe_ratio, sortino_ratio, calmar_ratio, max_drawdown, max_ac_bal, min_ac_bal, max_margin_used, total_streaks, avg_trades_per_streak, total_wins, max_win, avg_win, avg_win_duration, total_losses, max_loss, avg_loss, avg_loss_duration, total_long, avg_long, avg_long_duration, total_long_wins, avg_long_win, avg_long_win_duration, total_long_losses, avg_long_loss, avg_long_loss_duration, total_short, avg_short, avg_short_duration, total_short_wins, avg_short_win, avg_short_win_duration, total_short_losses, avg_short_loss, avg_short_loss_duration]
# Index: []

# %%
# figs1 = [
#             [px.scatter(df, x="cushion", y="return_%", color="init_signal", symbol="streak_limit"),
#             px.scatter(df, x="cushion", y="expectancy", color="init_signal", symbol="streak_limit")],
#             [px.scatter(df, x="cushion", y="win_%", color="init_signal", symbol="streak_limit"),
#             px.scatter(df, x="cushion", y="loss_%", color="init_signal", symbol="streak_limit")]
#     ]

# fig = make_subplots(
#     rows=2, cols=2,
#     subplot_titles=("return_%", "expectancy", "win_%", "loss_%"))

# for i, f1 in enumerate(figs1):
#     for j, f2 in enumerate(f1):
#         for trace in range(len(f2["data"])):
#             fig.append_trace(f2["data"][trace], row=i+1, col=j+1)
        
# fig.show()

# %%
px.scatter(df, x = 'rr', y = 'win_%', color = 'risk')

# %%
# win_% decreases with rr, lower rr higher win_%

# %%
px.scatter(df, x = 'risk', y = 'win_%', color='rr')

# %%
# win_% increases with risk if rr <= 2, higher risk higher win_% if rr <= 2

# %%
px.scatter(df, x = 'cushion', y = 'expectancy', color = 'rr', facet_col='risk')

# %%
px.scatter(df, x = 'cushion', y = 'expectancy', color = 'risk', facet_col='streak_limit')

# %%
# higher cushion, higher expectancy if risk >= 0.002

# %%
px.scatter(df, x = 'risk', y = 'expectancy', color = 'streak_limit', facet_col='streak_limit')

# %%
px.scatter(df, x = 'cushion', y = 'expectancy', color = 'streak_limit', facet_col='risk')

# %%
px.scatter(df, x = 'risk', y = 'max_loss')

# %%
# max loss decreases with risk, higher risk lower max loss

# %%
px.scatter(df, x='rr', y='max_loss', facet_col='streak_limit')

# %%
# max loss increases with lower rr but only for higher streak limits

# %%
px.scatter(df, x = 'risk', y = 'max_loss', color = 'streak_limit', facet_col='rr')

# %%
# max_loss decreases with risk, higher risk lower max loss

# %%
def plot_plots(df):  
    px.scatter(df, x = 'streak_limit', y = 'expectancy', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'return_%', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'max_margin_used', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'min_ac_bal', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'final_ac_bal', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'max_loss', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'max_win', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'sharpe_ratio', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'sortino_ratio', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'calmar_ratio', color = 'risk', facet_col='base_trade_size').show()
    px.scatter(df, x = 'streak_limit', y = 'max_drawdown', color = 'risk', facet_col='base_trade_size').show()

# %%
df1 = df[(df.risk>=0.003) & (df.rr <= 2) & (df.cushion==2)]
df1
# Out:
# Empty DataFrame
# Columns: [index, sim_name, init_signal, base_trade_size, cushion, risk, rr, margin_closeout, streak_limit, return_%, final_ac_bal, total_trades, avg_trade, avg_trade_duration, win_%, loss_%, expectancy, sharpe_ratio, sortino_ratio, calmar_ratio, max_drawdown, max_ac_bal, min_ac_bal, max_margin_used, total_streaks, avg_trades_per_streak, total_wins, max_win, avg_win, avg_win_duration, total_losses, max_loss, avg_loss, avg_loss_duration, total_long, avg_long, avg_long_duration, total_long_wins, avg_long_win, avg_long_win_duration, total_long_losses, avg_long_loss, avg_long_loss_duration, total_short, avg_short, avg_short_duration, total_short_wins, avg_short_win, avg_short_win_duration, total_short_losses, avg_short_loss, avg_short_loss_duration]
# Index: []

# %%
plot_plots(df)

# %%
df2 = df[(df.risk>=0.003) & (df.rr > 2)]# & (df.cushion==2) & (df.streak_limit<=7)]
df2.head()
# Out:
#    index  sim_name  init_signal  base_trade_size  cushion   risk  rr  \
# 1      1  sim_3002           -1               10      2.0  0.003   3
# 2      2  sim_3003            1               10      2.0  0.004   3
# 4      4  sim_3005           -1               50      2.0  0.003   3
# 5      5  sim_3006           -1               50      2.0  0.004   3
# 7      7  sim_3008            1              100      2.0  0.003   3
#
#    margin_closeout  streak_limit  return_%  final_ac_bal  total_trades  \
# 1             True            11 -0.079735     920.26476        2273.0
# 2             True            11  0.005429    1005.42937        1275.0
# 4             True            11 -0.378302     621.69840        2273.0
# 5             True            11  0.133203    1133.20294        1273.0
# 7             True            11 -0.688197     311.80338        2268.0
#
#    avg_trade  avg_trade_duration     win_%    loss_%  expectancy  \
# 1  -0.035079          261.448306  0.229212  0.770788   -0.035079
# 2   0.004258          465.818039  0.227451  0.772549    0.004258
# 4  -0.166433          261.448306  0.229212  0.770788   -0.166433
# 5   0.104637          466.549882  0.230165  0.769835    0.104637
# 7  -0.303438          262.024691  0.230600  0.769400   -0.303438
#
#    sharpe_ratio  sortino_ratio  calmar_ratio  max_drawdown  max_ac_bal  \
# 1     -0.056697      -0.086416     -0.129449     -0.087333  1000.08492
# 2      0.004840       0.009181      0.039667     -0.037013  1037.67452
# 4     -0.055288      -0.084468     -0.152067     -0.414005  1000.38772
# 5      0.027032       0.061645      0.233027     -0.141193  1285.61467
# 7     -0.047418      -0.072255     -0.188490     -0.769299  1046.03079
#
#    min_ac_bal  max_margin_used  total_streaks  avg_trades_per_streak  \
# 1   912.74466        23.600000          553.0               4.112116
# 2   979.22459        23.600000          304.0               4.197368
# 4   586.22174       111.566667          553.0               4.112116
# 5   987.39336       111.566667          305.0               4.177049
# 7   241.32081       221.666667          554.0               4.095668
#
#    total_wins   max_win   avg_win  avg_win_duration  total_losses  max_loss  \
# 1       521.0   7.50480  0.440882        441.865643        1752.0  -4.09224
# 2       290.0   9.01992  0.795488        770.944828         985.0  -7.35612
# 4       521.0  35.47820  2.088745        441.865643        1752.0 -19.34566
# 5       293.0  42.64078  3.749820        767.737201         980.0 -15.76437
# 7       523.0  70.49000  4.186368        441.541109        1745.0 -38.43700
#
#    avg_loss  avg_loss_duration  total_long  avg_long  avg_long_duration  \
# 1 -0.176618         207.796804      1138.0 -0.012442         248.965729
# 2 -0.228693         375.983756       638.0  0.027306         431.800940
# 4 -0.837065         207.796804      1138.0 -0.059510         248.965729
# 5 -0.985198         376.501020       636.0  0.164991         430.941824
# 7 -1.649093         208.221203      1136.0 -0.080632         249.495599
#
#    total_long_wins  avg_long_win  avg_long_win_duration  total_long_losses  \
# 1            262.0      0.543101             421.377863              876.0
# 2            145.0      0.880302             713.179310              493.0
# 4            262.0      2.571627             421.377863              876.0
# 5            146.0      3.987137             720.116438              490.0
# 7            263.0      5.159567             420.570342              873.0
#
#    avg_long_loss  avg_long_loss_duration  total_short  avg_short  \
# 1      -0.178598              197.399543       1135.0  -0.057776
# 2      -0.223575              349.042596        637.0  -0.018825
# 4      -0.846449              197.399543       1135.0  -0.273638
# 5      -0.973852              344.779592        637.0   0.044378
# 7      -1.659295              197.957617       1132.0  -0.527030
#
#    avg_short_duration  total_short_wins  avg_short_win  \
# 1          273.963877             259.0       0.337478
# 2          499.888540             145.0       0.710674
# 4          273.963877             259.0       1.600269
# 5          502.102041             147.0       3.514118
# 7          274.598057             260.0       3.201939
#
#    avg_short_win_duration  total_short_losses  avg_short_loss  \
# 1              462.590734               876.0       -0.174638
# 2              828.710345               492.0       -0.233820
# 4              462.590734               876.0       -0.827681
# 5              815.034014               490.0       -0.996544
# 7              462.753846               872.0       -1.638879
#
#    avg_short_loss_duration
# 1               218.194064
# 2               402.979675
# 4               218.194064
# 5               408.222449
# 7               218.496560

# %%
plot_plots(df2)

# %%
df3 = df[(df.risk>=0.003) & (df.rr == 1.5) & (df.cushion==2) & (df.streak_limit==5)]
df3
# Out:
# Empty DataFrame
# Columns: [index, sim_name, init_signal, base_trade_size, cushion, risk, rr, margin_closeout, streak_limit, return_%, final_ac_bal, total_trades, avg_trade, avg_trade_duration, win_%, loss_%, expectancy, sharpe_ratio, sortino_ratio, calmar_ratio, max_drawdown, max_ac_bal, min_ac_bal, max_margin_used, total_streaks, avg_trades_per_streak, total_wins, max_win, avg_win, avg_win_duration, total_losses, max_loss, avg_loss, avg_loss_duration, total_long, avg_long, avg_long_duration, total_long_wins, avg_long_win, avg_long_win_duration, total_long_losses, avg_long_loss, avg_long_loss_duration, total_short, avg_short, avg_short_duration, total_short_wins, avg_short_win, avg_short_win_duration, total_short_losses, avg_short_loss, avg_short_loss_duration]
# Index: []

# %%
def plot_plots(df):  
    px.scatter(df, x = 'init_signal', y = 'expectancy', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'return_%', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'max_margin_used', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'min_ac_bal', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'final_ac_bal', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'max_loss', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'max_win', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'sharpe_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'sortino_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'calmar_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'init_signal', y = 'max_drawdown', color = 'risk', facet_col='rr').show()

# %%
plot_plots(df3)

# %% [markdown]
# win_% decreases with rr, lower rr higher win_%
#
# win_% increases with risk, higher risk higher win_%
#
# expectancy increases with risk, higher risk higher expectancy
#
# init_signal has not effect on win_%

# %%
df1.sort_values(by='final_ac_bal')
# Out:
# Empty DataFrame
# Columns: [index, sim_name, init_signal, base_trade_size, cushion, risk, rr, margin_closeout, streak_limit, return_%, final_ac_bal, total_trades, avg_trade, avg_trade_duration, win_%, loss_%, expectancy, sharpe_ratio, sortino_ratio, calmar_ratio, max_drawdown, max_ac_bal, min_ac_bal, max_margin_used, total_streaks, avg_trades_per_streak, total_wins, max_win, avg_win, avg_win_duration, total_losses, max_loss, avg_loss, avg_loss_duration, total_long, avg_long, avg_long_duration, total_long_wins, avg_long_win, avg_long_win_duration, total_long_losses, avg_long_loss, avg_long_loss_duration, total_short, avg_short, avg_short_duration, total_short_wins, avg_short_win, avg_short_win_duration, total_short_losses, avg_short_loss, avg_short_loss_duration]
# Index: []

# %%
df.calmar_ratio.max()
# Out:
# 58.183786796999655

# %%
with open(PATH + 'sim_2250.pkl', 'rb') as f:
    tempdf = pkl.load(f)
tempdf = tempdf['results'].copy()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 with open(PATH + 'sim_2250.pkl', 'rb') as f:
#       2     tempdf = pkl.load(f)
#       3 tempdf = tempdf['results'].copy()
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/Trading/forex_bot/outputs/sim_2250.pkl'

# %%
trades = tempdf[tempdf.signal!=0].copy()
trades.head()

# %%
trades.ac_bal.pct_change().shift(-1)
px.histogram(x=trades.ac_bal.pct_change().shift(-1))

# %%
returns = trades['ac_bal'].shift(-1) - trades['ac_bal']
px.histogram(x=returns)

# %%
df.sort_values(by='final_ac_bal')
