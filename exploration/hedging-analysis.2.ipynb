# %%
import sys
sys.path.append("../")

# %%
import pandas as pd
import numpy as np
import datetime as dt
import math
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.offline import plot
from tqdm import tqdm
from tabulate import tabulate
import pickle as pkl
pd.set_option("display.max_columns", None)

# %%
class Data:
    
    def __init__(self, path):
        self.df = {
            'raw': pd.read_pickle(path)
        }
        if 'time' in self.df['raw'].columns:
            self.df['raw']['time'] = [ x.replace(tzinfo=None) for x in self.df['raw']['time']]

    def __repr__(self) -> str:
        repr = str()
        for name, df in self.df.items():
            repr = repr + name + ':\n' + str(df.head(3)) + '\n'
        return repr

    def shorten(self, name: str, rows: int, direction: int, source: str='raw', cols: list=None):
        '''Create new dataframe with specified list of columns and number of rows
        direction: 1 if data should be selected from top and -1 if from bottom
        '''
        assert (direction != 1 or direction != -1), 'direction must be 1 (top) or -1 (bottom)'
        
        if cols == None:
            cols = self.df[source].columns
        if direction == 1:
            self.df[name] = self.df[source][cols].iloc[:rows].copy()
        else:
            self.df[name] = self.df[source][cols].iloc[-rows:].copy()
        self.df[name].reset_index(drop=True, inplace=True)

    def add_columns(self, name: str, cols: list):
        '''Add new columns to component dataframes
        '''        
        exist_cols = list(self.df[name].columns)
        cols = exist_cols + cols
        self.df[name] = self.df[name].reindex(columns = cols) 

    def prepare_fast_data(self, name: str):
        '''Prepare data as an array for fast processing
        fcols = {col1: col1_index, col2: col2_index, .... }     
        fdata = [array[col1], array[col2], array[col3], .... ]
        Accessed by: self.fdata[fcols[column_name]] for whole column or
                     self.fdata[fcols[column_name]][row_index] for a specific row item
        '''
        self.fcols = dict()
        for i in range(len(self.df[name].columns)):
            self.fcols[self.df[name].columns[i]] = i
        self.fastdf = [self.df[name][col].array for col in self.df[name].columns]

    def fdata(self, column: str, index: int=-1):
        assert index >= -1, 'Row index cannot be negative'
        if index == -1:
            return self.fastdf[self.fcols[column]]
        else:
            return self.fastdf[self.fcols[column]][index]
        
    def update_fdata(self, column: str, value, index: int=-1):
        assert index >= -1, 'Row index cannot be negative'
        if index == -1:
            self.fastdf[self.fcols[column]] = value
        else:
            self.fastdf[self.fcols[column]][index] = value

# %%
PATH = 'D:/Trading/forex_bot/outputs/'

# %%
# files = ['inputs.2.1.pkl', 'inputs.2.2.pkl', 'inputs.2.3.pkl']

# %%
# dfs = list()
# for f in files:
#     dfs.append(pd.read_pickle(PATH + f))

# %%
# inputs = pd.concat(dfs)
# inputs.drop_duplicates(inplace=True)
# inputs.reset_index(drop=True,inplace=True)
# inputs

# %%
# inputs.to_pickle(PATH + 'inputs.2.all.pkl')

# %%
d = Data(PATH + "inputs.all.pkl")

# %%
subset = ['init_signal', 'cushion', 'risk', 'rr', 'margin_closeout', 'streak_limit']
d.df['raw'].drop_duplicates(subset=subset, keep='first', inplace=True)
d.df['raw'].reset_index(drop=True, inplace=True)

# %%
cols = ['return_%', 'final_ac_bal', 'total_trades', 'avg_trade', 'avg_trade_duration', 'win_%', 'loss_%', 
        'expectancy', 'sharpe_ratio', 'sortino_ratio', 'calmar_ratio',
        'max_drawdown', 'max_ac_bal', 'cagr', 'min_ac_bal', 'max_margin_used', 'total_streaks', 'avg_trades_per_streak',
        'total_wins', 'max_win', 'avg_win', 'avg_win_duration', 'total_losses', 'max_loss', 'avg_loss', 'avg_loss_duration',
        'total_long', 'avg_long', 'avg_long_duration',
        'total_long_wins', 'avg_long_win', 'avg_long_win_duration',
        'total_long_losses', 'avg_long_loss', 'avg_long_loss_duration',
        'total_short', 'avg_short', 'avg_short_duration',
        'total_short_wins', 'avg_short_win', 'avg_short_win_duration',
        'total_short_losses', 'avg_short_loss', 'avg_short_loss_duration',
        
        ]
d.add_columns('raw', cols)
d.df['raw'].head(3)
# Out:
#   sim_name  init_signal  cushion   risk   rr  margin_closeout  streak_limit  \
# 0    sim_1            1      1.5  0.001  1.5             True             1
# 1    sim_2            1      1.5  0.001  1.5             True             2
# 2    sim_3           -1      1.5  0.001  1.5             True             3
#
#    return_%  final_ac_bal  total_trades  avg_trade  avg_trade_duration  win_%  \
# 0       NaN           NaN           NaN        NaN                 NaN    NaN
# 1       NaN           NaN           NaN        NaN                 NaN    NaN
# 2       NaN           NaN           NaN        NaN                 NaN    NaN
#
#    loss_%  expectancy  sharpe_ratio  sortino_ratio  calmar_ratio  \
# 0     NaN         NaN           NaN            NaN           NaN
# 1     NaN         NaN           NaN            NaN           NaN
# 2     NaN         NaN           NaN            NaN           NaN
#
#    max_drawdown  max_ac_bal  cagr  min_ac_bal  max_margin_used  total_streaks  \
# 0           NaN         NaN   NaN         NaN              NaN            NaN
# 1           NaN         NaN   NaN         NaN              NaN            NaN
# 2           NaN         NaN   NaN         NaN              NaN            NaN
#
#    avg_trades_per_streak  total_wins  max_win  avg_win  avg_win_duration  \
# 0                    NaN         NaN      NaN      NaN               NaN
# 1                    NaN         NaN      NaN      NaN               NaN
# 2                    NaN         NaN      NaN      NaN               NaN
#
#    total_losses  max_loss  avg_loss  avg_loss_duration  total_long  avg_long  \
# 0           NaN       NaN       NaN                NaN         NaN       NaN
# 1           NaN       NaN       NaN                NaN         NaN       NaN
# 2           NaN       NaN       NaN                NaN         NaN       NaN
#
#    avg_long_duration  total_long_wins  avg_long_win  avg_long_win_duration  \
# 0                NaN              NaN           NaN                    NaN
# 1                NaN              NaN           NaN                    NaN
# 2                NaN              NaN           NaN                    NaN
#
#    total_long_losses  avg_long_loss  avg_long_loss_duration  total_short  \
# 0                NaN            NaN                     NaN          NaN
# 1                NaN            NaN                     NaN          NaN
# 2                NaN            NaN                     NaN          NaN
#
#    avg_short  avg_short_duration  total_short_wins  avg_short_win  \
# 0        NaN                 NaN               NaN            NaN
# 1        NaN                 NaN               NaN            NaN
# 2        NaN                 NaN               NaN            NaN
#
#    avg_short_win_duration  total_short_losses  avg_short_loss  \
# 0                     NaN                 NaN             NaN
# 1                     NaN                 NaN             NaN
# 2                     NaN                 NaN             NaN
#
#    avg_short_loss_duration
# 0                      NaN
# 1                      NaN
# 2                      NaN

# %%
d.prepare_fast_data('raw')

# %%
d.fdata('sim_name', 0)
# Out:
# 'sim_1'

# %%
def convert2date(date_time):
    return date_time.date().strftime("%Y-%m-%d")

# %%
def sharpe_ratio(returns: pd.Series, risk_free_rate: float=0) -> float:
    return (returns.mean() - risk_free_rate) / returns.std()

def sortino_ratio(returns: pd.Series, risk_free_rate: float=0, target_return: float=0) -> float:
    downside_returns = np.array([ret - risk_free_rate for ret in returns if ret < target_return])
    std_dev_downside = np.std(downside_returns, ddof=1) if len(downside_returns) > 0 else 0
    return (np.mean(returns) - risk_free_rate) / std_dev_downside if std_dev_downside != 0 else np.nan

def max_drawdown(returns: pd.Series) -> float:
    '''
    cum_returns: Calculates the cumulative returns using np.cumprod(1 + returns).
    peaks: Finds the peaks in the cumulative returns using np.maximum.accumulate(cum_returns).
    drawdowns: Calculates the drawdowns for each point by subtracting the peaks from the cumulative returns and dividing by the peaks.
    max_drawdown: Identifies the maximum drawdown by finding the minimum drawdown value using np.min(drawdowns).'''
    cum_returns = np.cumprod(1 + returns.values)
    peaks = np.maximum.accumulate(cum_returns)
    drawdowns = (cum_returns - peaks) / peaks
    max_drawdown = np.min(drawdowns)
    return max_drawdown

def calmar_ratio(returns: pd.Series):
    max_drawdown_value = max_drawdown(returns)
    annual_return = np.mean(returns) * 311  # Assuming 311 trading days per year for forex. Its usually 252 for stocks
    return annual_return / abs(max_drawdown_value)

def cagr(ac_bal: pd.Series, years: float) -> float:
    return (ac_bal.iloc[-1] / ac_bal.iloc[0]) ** (1 / years) - 1

# %%
def populate_results(d: Data, i: int, df: pd.DataFrame):
    d.update_fdata('return_%', (df['ac_bal'].iloc[-1] - df['ac_bal'].iloc[0]) / df['ac_bal'].iloc[0], i)
    d.update_fdata('final_ac_bal', df['ac_bal'].iloc[-1], i)
    d.update_fdata('cagr', cagr(df['ac_bal'], 8), i)
    d.update_fdata('max_ac_bal', df['ac_bal'].max(), i)
    d.update_fdata('min_ac_bal', df['ac_bal'].min(), i)
    d.update_fdata('max_margin_used', df['margin_used'].max(), i)
    d.update_fdata('total_streaks', df['streak_no'].iloc[-1], i)
    d.update_fdata('avg_trades_per_streak', df.groupby('streak_no')['trade_no'].max().mean(), i)
    
    trades = df[df.signal != 0].copy()
    trades['return'] = trades['ac_bal'].shift(-1) - trades['ac_bal']
    trades['return_%'] = trades['ac_bal'].pct_change().shift(-1)
    trades['index'] = trades.index
    trades['duration'] = trades['index'].shift(-1) - trades['index']
    trades.dropna(inplace=True)
    # print(trades[['ac_bal', 'return', 'return_%']].head())

    d.update_fdata('sharpe_ratio', sharpe_ratio(trades['return_%']), i)
    d.update_fdata('sortino_ratio', sortino_ratio(trades['return_%']), i)
    d.update_fdata('calmar_ratio', calmar_ratio(trades['return_%']), i)
    d.update_fdata('max_drawdown', max_drawdown(trades['return_%']), i)

    d.update_fdata('total_trades', trades.shape[0], i)
    d.update_fdata('avg_trade', trades['return'].mean(), i)
    d.update_fdata('avg_trade_duration', trades['duration'].mean(), i)
    
    wins = trades[trades['return'] > 0]
    d.update_fdata('total_wins', wins.shape[0], i)
    d.update_fdata('max_win', wins['return'].max(), i)
    d.update_fdata('avg_win', wins['return'].mean(), i)
    d.update_fdata('avg_win_duration', wins['duration'].mean(), i)
    d.update_fdata('win_%', d.fdata('total_wins', i) / d.fdata('total_trades', i), i)

    losses = trades[trades['return'] < 0]
    d.update_fdata('total_losses', losses.shape[0], i)
    d.update_fdata('max_loss', losses['return'].min(), i)
    d.update_fdata('avg_loss', losses['return'].mean(), i)
    d.update_fdata('avg_loss_duration', losses['duration'].mean(), i)
    d.update_fdata('loss_%', d.fdata('total_losses', i) / d.fdata('total_trades', i), i)
    
    longs = trades[trades.signal == 1]
    d.update_fdata('total_long', longs.shape[0], i)
    d.update_fdata('avg_long', longs['return'].mean(), i)
    d.update_fdata('avg_long_duration', longs['duration'].mean(), i)

    long_wins = longs[longs['return'] > 0]
    d.update_fdata('total_long_wins', long_wins.shape[0], i)
    d.update_fdata('avg_long_win', long_wins['return'].mean(), i)
    d.update_fdata('avg_long_win_duration', long_wins['duration'].mean(), i)

    long_losses = longs[longs['return'] < 0]
    d.update_fdata('total_long_losses', long_losses.shape[0], i)
    d.update_fdata('avg_long_loss', long_losses['return'].mean(), i)
    d.update_fdata('avg_long_loss_duration', long_losses['duration'].mean(), i)

    shorts = trades[trades.signal == -1]
    d.update_fdata('total_short', shorts.shape[0], i)
    d.update_fdata('avg_short', shorts['return'].mean(), i)
    d.update_fdata('avg_short_duration', shorts['duration'].mean(), i)

    short_wins = shorts[shorts['return'] > 0]
    d.update_fdata('total_short_wins', short_wins.shape[0], i)
    d.update_fdata('avg_short_win', short_wins['return'].mean(), i)
    d.update_fdata('avg_short_win_duration', short_wins['duration'].mean(), i)

    short_losses = shorts[shorts['return'] < 0]
    d.update_fdata('total_short_losses', short_losses.shape[0], i)
    d.update_fdata('avg_short_loss', short_losses['return'].mean(), i)
    d.update_fdata('avg_short_loss_duration', short_losses['duration'].mean(), i)


    d.update_fdata('expectancy', d.fdata('win_%', i) * d.fdata('avg_win', i) + d.fdata('loss_%', i) * d.fdata('avg_loss', i), i)

# %%
# def populate_results(d: Data, i: int, data: Data):
#     df = data['results'].copy()
#     d.update_fdata('return_%', (df['ac_bal'].iloc[-1] - df['ac_bal'].iloc[0]) / df['ac_bal'].iloc[0], i)
#     d.update_fdata('final_ac_bal', df['ac_bal'].iloc[-1], i)
#     d.update_fdata('cagr', cagr(df['ac_bal'], 8), i)
#     d.update_fdata('max_ac_bal', df['ac_bal'].max(), i)
#     d.update_fdata('min_ac_bal', df['ac_bal'].min(), i)
#     d.update_fdata('max_margin_used', df['margin_used'].max(), i)
#     d.update_fdata('total_streaks', df['streak_no'].iloc[-1], i)
#     d.update_fdata('avg_trades_per_streak', df.groupby('streak_no')['trade_no'].max().mean(), i)
    
#     trades = df[df.signal != 0].copy()
#     trades['return'] = trades['ac_bal'].shift(-1) - trades['ac_bal']
#     trades['return_%'] = trades['ac_bal'].pct_change().shift(-1)
#     trades['index'] = trades.index
#     trades['duration'] = trades['index'].shift(-1) - trades['index']
#     trades.dropna(inplace=True)
#     # print(trades[['ac_bal', 'return', 'return_%']].head())

#     d.update_fdata('sharpe_ratio', sharpe_ratio(trades['return_%']), i)
#     d.update_fdata('sortino_ratio', sortino_ratio(trades['return_%']), i)
#     d.update_fdata('calmar_ratio', calmar_ratio(trades['return_%']), i)
#     d.update_fdata('max_drawdown', max_drawdown(trades['return_%']), i)

#     d.update_fdata('total_trades', trades.shape[0], i)
#     d.update_fdata('avg_trade', trades['return'].mean(), i)
#     d.update_fdata('avg_trade_duration', trades['duration'].mean(), i)
    
#     wins = trades[trades['return'] > 0]
#     d.update_fdata('total_wins', wins.shape[0], i)
#     d.update_fdata('max_win', wins['return'].max(), i)
#     d.update_fdata('avg_win', wins['return'].mean(), i)
#     d.update_fdata('avg_win_duration', wins['duration'].mean(), i)
#     d.update_fdata('win_%', d.fdata('total_wins', i) / d.fdata('total_trades', i), i)

#     losses = trades[trades['return'] < 0]
#     d.update_fdata('total_losses', losses.shape[0], i)
#     d.update_fdata('max_loss', losses['return'].min(), i)
#     d.update_fdata('avg_loss', losses['return'].mean(), i)
#     d.update_fdata('avg_loss_duration', losses['duration'].mean(), i)
#     d.update_fdata('loss_%', d.fdata('total_losses', i) / d.fdata('total_trades', i), i)
    
#     longs = trades[trades.signal == 1]
#     d.update_fdata('total_long', longs.shape[0], i)
#     d.update_fdata('avg_long', longs['return'].mean(), i)
#     d.update_fdata('avg_long_duration', longs['duration'].mean(), i)

#     long_wins = longs[longs['return'] > 0]
#     d.update_fdata('total_long_wins', long_wins.shape[0], i)
#     d.update_fdata('avg_long_win', long_wins['return'].mean(), i)
#     d.update_fdata('avg_long_win_duration', long_wins['duration'].mean(), i)

#     long_losses = longs[longs['return'] < 0]
#     d.update_fdata('total_long_losses', long_losses.shape[0], i)
#     d.update_fdata('avg_long_loss', long_losses['return'].mean(), i)
#     d.update_fdata('avg_long_loss_duration', long_losses['duration'].mean(), i)

#     shorts = trades[trades.signal == -1]
#     d.update_fdata('total_short', shorts.shape[0], i)
#     d.update_fdata('avg_short', shorts['return'].mean(), i)
#     d.update_fdata('avg_short_duration', shorts['duration'].mean(), i)

#     short_wins = shorts[shorts['return'] > 0]
#     d.update_fdata('total_short_wins', short_wins.shape[0], i)
#     d.update_fdata('avg_short_win', short_wins['return'].mean(), i)
#     d.update_fdata('avg_short_win_duration', short_wins['duration'].mean(), i)

#     short_losses = shorts[shorts['return'] < 0]
#     d.update_fdata('total_short_losses', short_losses.shape[0], i)
#     d.update_fdata('avg_short_loss', short_losses['return'].mean(), i)
#     d.update_fdata('avg_short_loss_duration', short_losses['duration'].mean(), i)


#     d.update_fdata('expectancy', d.fdata('win_%', i) * d.fdata('avg_win', i) + d.fdata('loss_%', i) * d.fdata('avg_loss', i), i)

# %%
sims = d.df['raw'].shape[0]
for i in tqdm(range(sims), desc=" Analysing... "):
# for i in tqdm(range(2), desc=" Analysing... "):
    data = pd.read_pickle(PATH + d.fdata('sim_name', i) + '.pkl')
    assert (d.fdata('sim_name', i) == data['sim_name'] and
            d.fdata('init_signal', i) == data['init_signal'] and
            d.fdata('cushion', i) == data['cushion'] and
            d.fdata('risk', i) == data['risk'] and
            d.fdata('rr', i) == data['rr'] and
            d.fdata('margin_closeout', i) == data['margin_closeout'] and
            d.fdata('streak_limit', i) == data['streak_limit']), f"Parameters mismatch for {d.fdata('sim_name', i)}"
    
    populate_results(d, i, data['results'])
# Out:
#  Analysing... :   0%|          | 0/540 [00:00<?, ?it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   0%|          | 1/540 [00:00<01:21,  6.64it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   0%|          | 2/540 [00:00<01:17,  6.97it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   1%|          | 3/540 [00:00<01:12,  7.44it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
# C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   1%|          | 5/540 [00:00<00:58,  9.09it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
# C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   1%|▏         | 7/540 [00:00<00:52, 10.20it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
# C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   2%|▏         | 9/540 [00:00<00:47, 11.12it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
# C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   2%|▏         | 11/540 [00:01<00:52, 10.14it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
# C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   2%|▏         | 13/540 [00:01<00:54,  9.64it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   3%|▎         | 14/540 [00:01<01:00,  8.68it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   3%|▎         | 15/540 [00:01<01:03,  8.28it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   3%|▎         | 16/540 [00:01<01:01,  8.50it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   3%|▎         | 17/540 [00:01<00:59,  8.73it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   3%|▎         | 18/540 [00:01<00:58,  8.95it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
# C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   4%|▎         | 20/540 [00:02<00:54,  9.48it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   4%|▍         | 24/540 [00:02<01:01,  8.41it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   5%|▍         | 25/540 [00:02<01:07,  7.64it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   5%|▍         | 26/540 [00:03<01:13,  7.03it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   5%|▌         | 27/540 [00:03<01:16,  6.67it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   5%|▌         | 28/540 [00:03<01:17,  6.59it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   5%|▌         | 29/540 [00:03<01:17,  6.61it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   6%|▌         | 30/540 [00:03<01:13,  6.93it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   7%|▋         | 36/540 [00:04<01:07,  7.47it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   7%|▋         | 37/540 [00:04<01:16,  6.55it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   7%|▋         | 38/540 [00:04<01:23,  6.03it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   7%|▋         | 39/540 [00:04<01:24,  5.92it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   7%|▋         | 40/540 [00:05<01:19,  6.26it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   8%|▊         | 41/540 [00:05<01:20,  6.23it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   8%|▊         | 42/540 [00:05<01:19,  6.30it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   8%|▊         | 43/540 [00:05<01:16,  6.46it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   8%|▊         | 44/540 [00:05<01:16,  6.47it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   8%|▊         | 45/540 [00:05<01:15,  6.59it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   9%|▊         | 46/540 [00:06<01:13,  6.70it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   9%|▊         | 47/540 [00:06<01:12,  6.76it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   9%|▉         | 48/540 [00:06<01:13,  6.67it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   9%|▉         | 49/540 [00:06<01:21,  6.04it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   9%|▉         | 50/540 [00:06<01:26,  5.69it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :   9%|▉         | 51/540 [00:06<01:29,  5.49it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  10%|▉         | 52/540 [00:07<01:28,  5.53it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  10%|▉         | 53/540 [00:07<01:26,  5.61it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  10%|█         | 54/540 [00:07<01:24,  5.73it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  10%|█         | 55/540 [00:07<01:24,  5.77it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  10%|█         | 56/540 [00:07<01:26,  5.61it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  11%|█         | 60/540 [00:08<01:16,  6.26it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  11%|█▏        | 61/540 [00:08<01:20,  5.96it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  11%|█▏        | 62/540 [00:08<01:22,  5.81it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  12%|█▏        | 63/540 [00:08<01:23,  5.71it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  12%|█▏        | 64/540 [00:09<01:19,  5.97it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  12%|█▏        | 65/540 [00:09<01:17,  6.15it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  12%|█▏        | 66/540 [00:09<01:16,  6.23it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  12%|█▏        | 67/540 [00:09<01:12,  6.48it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  13%|█▎        | 68/540 [00:09<01:09,  6.83it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  13%|█▎        | 72/540 [00:10<01:01,  7.59it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  14%|█▎        | 73/540 [00:10<01:07,  6.90it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  14%|█▎        | 74/540 [00:10<01:14,  6.26it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  14%|█▍        | 75/540 [00:10<01:17,  6.03it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  14%|█▍        | 76/540 [00:10<01:13,  6.31it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  14%|█▍        | 77/540 [00:11<01:11,  6.49it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  14%|█▍        | 78/540 [00:11<01:10,  6.51it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  15%|█▍        | 79/540 [00:11<01:08,  6.75it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  15%|█▍        | 80/540 [00:11<01:05,  6.98it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  15%|█▌        | 81/540 [00:11<01:04,  7.13it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  15%|█▌        | 82/540 [00:11<01:02,  7.32it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  15%|█▌        | 83/540 [00:11<01:01,  7.41it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  16%|█▌        | 84/540 [00:11<01:02,  7.32it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  16%|█▌        | 85/540 [00:12<01:06,  6.80it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  16%|█▌        | 86/540 [00:12<01:08,  6.61it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  16%|█▌        | 87/540 [00:12<01:11,  6.33it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  16%|█▋        | 88/540 [00:12<01:09,  6.55it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  16%|█▋        | 89/540 [00:12<01:09,  6.48it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  17%|█▋        | 90/540 [00:12<01:06,  6.76it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  17%|█▋        | 91/540 [00:13<01:04,  6.93it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  17%|█▋        | 92/540 [00:13<01:04,  6.90it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  18%|█▊        | 96/540 [00:13<00:58,  7.57it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  18%|█▊        | 97/540 [00:13<01:02,  7.08it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  18%|█▊        | 98/540 [00:14<01:04,  6.85it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  18%|█▊        | 99/540 [00:14<01:06,  6.64it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  19%|█▊        | 100/540 [00:14<01:05,  6.71it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  19%|█▊        | 101/540 [00:14<01:03,  6.89it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  19%|█▉        | 102/540 [00:14<01:02,  7.04it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  19%|█▉        | 103/540 [00:14<01:00,  7.21it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  19%|█▉        | 104/540 [00:14<00:59,  7.36it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  20%|██        | 108/540 [00:15<00:56,  7.60it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  20%|██        | 109/540 [00:15<01:02,  6.85it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  20%|██        | 110/540 [00:15<01:06,  6.50it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  21%|██        | 111/540 [00:15<01:10,  6.11it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  21%|██        | 112/540 [00:16<01:08,  6.22it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  21%|██        | 113/540 [00:16<01:06,  6.41it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  21%|██        | 114/540 [00:16<01:04,  6.64it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  21%|██▏       | 115/540 [00:16<01:01,  6.88it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  21%|██▏       | 116/540 [00:16<00:59,  7.08it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  22%|██▏       | 117/540 [00:16<00:58,  7.23it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  22%|██▏       | 118/540 [00:16<00:57,  7.35it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  22%|██▏       | 119/540 [00:17<00:55,  7.52it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  22%|██▏       | 120/540 [00:17<00:55,  7.57it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  22%|██▏       | 121/540 [00:17<00:59,  7.06it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  23%|██▎       | 122/540 [00:17<01:07,  6.21it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  23%|██▎       | 123/540 [00:17<01:09,  6.01it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  23%|██▎       | 124/540 [00:17<01:05,  6.36it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  23%|██▎       | 125/540 [00:18<01:05,  6.32it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  23%|██▎       | 126/540 [00:18<01:02,  6.58it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  24%|██▎       | 127/540 [00:18<01:00,  6.84it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  24%|██▎       | 128/540 [00:18<00:58,  7.04it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  24%|██▍       | 132/540 [00:18<00:55,  7.35it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  25%|██▍       | 133/540 [00:19<00:57,  7.13it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  25%|██▍       | 134/540 [00:19<00:58,  6.90it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  25%|██▌       | 135/540 [00:19<01:00,  6.74it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  25%|██▌       | 136/540 [00:19<00:58,  6.85it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  25%|██▌       | 137/540 [00:19<00:57,  7.02it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  26%|██▌       | 138/540 [00:19<00:55,  7.20it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  26%|██▌       | 139/540 [00:19<00:54,  7.31it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  26%|██▌       | 140/540 [00:20<00:54,  7.35it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  26%|██▋       | 143/540 [00:20<00:52,  7.58it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  27%|██▋       | 144/540 [00:20<00:51,  7.65it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  27%|██▋       | 145/540 [00:20<00:56,  6.94it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  27%|██▋       | 146/540 [00:20<01:01,  6.39it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  27%|██▋       | 147/540 [00:21<01:06,  5.91it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  27%|██▋       | 148/540 [00:21<01:04,  6.11it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  28%|██▊       | 149/540 [00:21<01:01,  6.33it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  28%|██▊       | 150/540 [00:21<00:59,  6.51it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  28%|██▊       | 151/540 [00:21<00:57,  6.73it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  28%|██▊       | 152/540 [00:21<00:55,  6.93it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  28%|██▊       | 153/540 [00:22<00:56,  6.90it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  29%|██▊       | 154/540 [00:22<00:57,  6.66it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  29%|██▊       | 155/540 [00:22<00:55,  6.97it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  29%|██▉       | 156/540 [00:22<00:53,  7.16it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  29%|██▉       | 157/540 [00:22<00:56,  6.78it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  29%|██▉       | 158/540 [00:22<00:58,  6.54it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  29%|██▉       | 159/540 [00:22<00:59,  6.36it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  30%|██▉       | 160/540 [00:23<00:58,  6.51it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  30%|██▉       | 161/540 [00:23<00:56,  6.71it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  30%|███       | 162/540 [00:23<00:55,  6.87it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  30%|███       | 163/540 [00:23<00:53,  7.04it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  30%|███       | 164/540 [00:23<00:52,  7.22it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  31%|███       | 167/540 [00:24<00:51,  7.30it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  31%|███       | 168/540 [00:24<00:49,  7.45it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  31%|███▏      | 169/540 [00:24<00:52,  7.09it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  31%|███▏      | 170/540 [00:24<00:54,  6.82it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  32%|███▏      | 171/540 [00:24<00:55,  6.65it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  32%|███▏      | 172/540 [00:24<00:53,  6.89it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  32%|███▏      | 173/540 [00:24<00:55,  6.63it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  32%|███▏      | 174/540 [00:25<00:53,  6.89it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  32%|███▏      | 175/540 [00:25<00:51,  7.15it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  33%|███▎      | 176/540 [00:25<00:50,  7.25it/s]C:\Users\souvi\AppData\Local\Temp\ipykernel_9352\2254183282.py:27: RuntimeWarning:
#
# invalid value encountered in scalar power
#
#  Analysing... :  33%|███▎      | 178/540 [00:25<00:52,  6.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 13
#       4 data = pd.read_pickle(PATH + d.fdata('sim_name', i) + '.pkl')
#       5 assert (d.fdata('sim_name', i) == data['sim_name'] and
#       6         d.fdata('init_signal', i) == data['init_signal'] and
#       7         d.fdata('cushion', i) == data['cushion'] and
#    (...)
#      10         d.fdata('margin_closeout', i) == data['margin_closeout'] and
#      11         d.fdata('streak_limit', i) == data['streak_limit']), f"Parameters mismatch for {d.fdata('sim_name', i)}"
# ---> 13 populate_results(d, i, data['results'])
#
# Cell In[16], line 35, in populate_results(d, i, df)
#      32 d.update_fdata('avg_win_duration', wins['duration'].mean(), i)
#      33 d.update_fdata('win_%', d.fdata('total_wins', i) / d.fdata('total_trades', i), i)
# ---> 35 losses = trades[trades['return'] < 0]
#      36 d.update_fdata('total_losses', losses.shape[0], i)
#      37 d.update_fdata('max_loss', losses['return'].min(), i)
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\frame.py:3884, in DataFrame.__getitem__(self, key)
#    3882 # Do we have a (boolean) 1d indexer?
#    3883 if com.is_bool_indexer(key):
# -> 3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#    3888 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\frame.py:3946, in DataFrame._getitem_bool_array(self, key)
#    3943     return self.copy(deep=None)
#    3945 indexer = key.nonzero()[0]
# -> 3946 return self._take_with_is_copy(indexer, axis=0)
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\generic.py:4088, in NDFrame._take_with_is_copy(self, indices, axis)
#    4077 @final
#    4078 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4079     """
#    4080     Internal version of the `take` method that sets the `_is_copy`
#    4081     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4086     See the docstring of `take` for full explanation of the parameters.
#    4087     """
# -> 4088     result = self.take(indices=indices, axis=axis)
#    4089     # Maybe set copy if we didn't actually change the index.
#    4090     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\internals\managers.py:877, in BaseBlockManager.take(self, indexer, axis, verify)
#     874 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     876 new_labels = self.axes[axis].take(indexer)
# --> 877 return self.reindex_indexer(
#     878     new_axis=new_labels,
#     879     indexer=indexer,
#     880     axis=axis,
#     881     allow_dups=True,
#     882     copy=None,
#     883 )
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\internals\managers.py:670, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     663     new_blocks = self._slice_take_blocks_ax0(
#     664         indexer,
#     665         fill_value=fill_value,
#     666         only_slice=only_slice,
#     667         use_na_proxy=use_na_proxy,
#     668     )
#     669 else:
# --> 670     new_blocks = [
#     671         blk.take_nd(
#     672             indexer,
#     673             axis=1,
#     674             fill_value=(
#     675                 fill_value if fill_value is not None else blk.fill_value
#     676             ),
#     677         )
#     678         for blk in self.blocks
#     679     ]
#     681 new_axes = list(self.axes)
#     682 new_axes[axis] = new_axis
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\internals\managers.py:671, in <listcomp>(.0)
#     663     new_blocks = self._slice_take_blocks_ax0(
#     664         indexer,
#     665         fill_value=fill_value,
#     666         only_slice=only_slice,
#     667         use_na_proxy=use_na_proxy,
#     668     )
#     669 else:
#     670     new_blocks = [
# --> 671         blk.take_nd(
#     672             indexer,
#     673             axis=1,
#     674             fill_value=(
#     675                 fill_value if fill_value is not None else blk.fill_value
#     676             ),
#     677         )
#     678         for blk in self.blocks
#     679     ]
#     681 new_axes = list(self.axes)
#     682 new_axes[axis] = new_axis
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\internals\blocks.py:1061, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1058     allow_fill = True
#    1060 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1061 new_values = algos.take_nd(
#    1062     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1063 )
#    1065 # Called from three places in managers, all of which satisfy
#    1066 #  these assertions
#    1067 if isinstance(self, ExtensionBlock):
#    1068     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1069     #  algos.take_nd call above.
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\array_algos\take.py:111, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     108     if not is_1d_only_ea_dtype(arr.dtype):
#     109         # i.e. DatetimeArray, TimedeltaArray
#     110         arr = cast("NDArrayBackedExtensionArray", arr)
# --> 111         return arr.take(
#     112             indexer, fill_value=fill_value, allow_fill=allow_fill, axis=axis
#     113         )
#     115     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     117 arr = np.asarray(arr)
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\arrays\_mixins.py:160, in NDArrayBackedExtensionArray.take(self, indices, allow_fill, fill_value, axis)
#     157 if allow_fill:
#     158     fill_value = self._validate_scalar(fill_value)
# --> 160 new_data = take(
#     161     self._ndarray,
#     162     indices,
#     163     allow_fill=allow_fill,
#     164     fill_value=fill_value,
#     165     axis=axis,
#     166 )
#     167 return self._from_backing_data(new_data)
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\algorithms.py:1314, in take(arr, indices, axis, allow_fill, fill_value)
#    1311 if allow_fill:
#    1312     # Pandas style, -1 means NA
#    1313     validate_indices(indices, arr.shape[axis])
# -> 1314     result = take_nd(
#    1315         arr, indices, axis=axis, allow_fill=True, fill_value=fill_value
#    1316     )
#    1317 else:
#    1318     # NumPy style
#    1319     result = arr.take(indices, axis=axis)
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\array_algos\take.py:118, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     115     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     117 arr = np.asarray(arr)
# --> 118 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\array_algos\take.py:163, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     158     out = np.empty(out_shape, dtype=dtype)
#     160 func = _get_take_nd_function(
#     161     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162 )
# --> 163 func(arr, indexer, out, fill_value)
#     165 if flip_order:
#     166     out = out.T
#
# File c:\Users\souvi\miniconda3\envs\trade\lib\site-packages\pandas\core\array_algos\take.py:370, in _view_wrapper.<locals>.wrapper(arr, indexer, out, fill_value)
#     367         fill_value = fill_value.astype("M8[ns]")
#     368     fill_value = fill_wrap(fill_value)
# --> 370 f(arr, indexer, out, fill_value=fill_value)
#
# KeyboardInterrupt:

# %%
data

# %%
with open(PATH + 'hedging_sim_analysis.2.pkl', 'wb') as file:
    pkl.dump(d.df['raw'], file)

# %%
d.df['raw'].head()

# %%
with open(PATH + 'hedging_sim_analysis.2.pkl', 'rb') as f:
    df_all = pkl.load(f)

# %%
df_all.drop_duplicates(subset=['init_signal', 'cushion', 'risk', 'rr', 'margin_closeout', 'streak_limit'],keep='first')
df_all

# %%
df = df_all[df_all.margin_closeout == True].copy()
df.reset_index(inplace=True)
df

# %%
df0 = df_all[df_all.margin_closeout == False].copy()
df0.reset_index(inplace=True)
df0

# %%
# figs1 = [
#             [px.scatter(df, x="cushion", y="return_%", color="init_signal", symbol="streak_limit"),
#             px.scatter(df, x="cushion", y="expectancy", color="init_signal", symbol="streak_limit")],
#             [px.scatter(df, x="cushion", y="win_%", color="init_signal", symbol="streak_limit"),
#             px.scatter(df, x="cushion", y="loss_%", color="init_signal", symbol="streak_limit")]
#     ]

# fig = make_subplots(
#     rows=2, cols=2,
#     subplot_titles=("return_%", "expectancy", "win_%", "loss_%"))

# for i, f1 in enumerate(figs1):
#     for j, f2 in enumerate(f1):
#         for trace in range(len(f2["data"])):
#             fig.append_trace(f2["data"][trace], row=i+1, col=j+1)
        
# fig.show()

# %%
px.scatter(df, x = 'rr', y = 'win_%', color = 'risk')

# %%
# win_% decreases with rr, lower rr higher win_%

# %%
px.scatter(df, x = 'risk', y = 'win_%', color='rr')

# %%
# win_% increases with risk if rr <= 2, higher risk higher win_% if rr <= 2

# %%
px.scatter(df, x = 'cushion', y = 'expectancy', color = 'rr', facet_col='risk')

# %%
px.scatter(df, x = 'cushion', y = 'expectancy', color = 'risk', facet_col='streak_limit')

# %%
# higher cushion, higher expectancy if risk >= 0.002

# %%
px.scatter(df, x = 'risk', y = 'expectancy', color = 'streak_limit', facet_col='streak_limit')

# %%
px.scatter(df, x = 'cushion', y = 'expectancy', color = 'streak_limit', facet_col='risk')

# %%
px.scatter(df, x = 'risk', y = 'max_loss')

# %%
# max loss decreases with risk, higher risk lower max loss

# %%
px.scatter(df, x='rr', y='max_loss', facet_col='streak_limit')

# %%
# max loss increases with lower rr but only for higher streak limits

# %%
px.scatter(df, x = 'risk', y = 'max_loss', color = 'streak_limit', facet_col='rr')

# %%
# max_loss decreases with risk, higher risk lower max loss

# %%
def plot_plots(df):  
    px.scatter(df, x = 'streak_limit', y = 'expectancy', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'return_%', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_margin_used', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'min_ac_bal', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'final_ac_bal', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_loss', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_win', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'sharpe_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'sortino_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'calmar_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_drawdown', color = 'risk', facet_col='rr').show()

# %%
df1 = df[(df.risk>=0.003) & (df.rr <= 2) & (df.cushion<=3)]
df1

# %%
plot_plots(df1)

# %%
def plot_plots(df):  
    px.scatter(df, x = 'streak_limit', y = 'expectancy', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'expectancy', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'return_%', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'return_%', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_margin_used', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_margin_used', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'min_ac_bal', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'min_ac_bal', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'final_ac_bal', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'final_ac_bal', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_loss', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_loss', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_win', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_win', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'sharpe_ratio', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'sharpe_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'sortino_ratio', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'sortino_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'calmar_ratio', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'calmar_ratio', color = 'risk', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_drawdown', color = 'cushion', facet_col='rr').show()
    px.scatter(df, x = 'streak_limit', y = 'max_drawdown', color = 'risk', facet_col='rr').show()

# %%
plot_plots(df1)

# %%
df2 = df1[df1.rr==1.5].copy()
df2.head()

# %%
def plot_plots(df):  
    px.scatter(df, x = 'streak_limit', y = 'expectancy', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'return_%', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'cagr', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'max_margin_used', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'min_ac_bal', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'final_ac_bal', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'max_loss', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'max_win', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'sharpe_ratio', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'sortino_ratio', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'calmar_ratio', color = 'cushion', facet_col='risk').show()
    px.scatter(df, x = 'streak_limit', y = 'max_drawdown', color = 'cushion', facet_col='risk').show()

# %%
plot_plots(df2)

# %%
df_final = df[(df.rr == 1.5) & (df.risk == 0.004) & (df.cushion == 2) & (df.streak_limit == 5)]
df_final

# %%
40 * 10 ** -4

# %% [markdown]
# win_% decreases with rr, lower rr higher win_%
#
# win_% increases with risk, higher risk higher win_%
#
# expectancy increases with risk, higher risk higher expectancy
#
# init_signal has not effect on win_%

# %%
df1.sort_values(by='final_ac_bal')

# %%
df.calmar_ratio.max()

# %%
with open(PATH + 'sim_2250.pkl', 'rb') as f:
    tempdf = pkl.load(f)
tempdf = tempdf['results'].copy()

# %%
trades = tempdf[tempdf.signal!=0].copy()
trades.head()

# %%
trades.ac_bal.pct_change().shift(-1)
px.histogram(x=trades.ac_bal.pct_change().shift(-1))

# %%
returns = trades['ac_bal'].shift(-1) - trades['ac_bal']
px.histogram(x=returns)

# %%
df.sort_values(by='final_ac_bal')
